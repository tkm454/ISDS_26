# %% [markdown]
# # Videos and Exercises for Session 5: Strings, Requests and APIs

# %% [markdown]
# In Assignment 0 we covered a lot about basic Python, and in the first sessions, we talked a bit about how to deal with different data types in pandas - strings among other. However, we only scratched the surface on string-related topics and in this session, we will be taking a deeper looking at.
#
# We will start out with a recap of some basic string operations and build on that to make a query for fetching data. After having finished this combined teaching module and exercise set, you will know the basics of collecting from the web. This notebook is structured as follows:
# 1. String Operations (recap and warm-up):
#     - Common string operations
#     - More string operations
#     - Warm-up exercises
# 2. Saving as Text File
# 3. Python Containers and Dictionaries
# 4. Python and the Web
#     - Application Programming Interface (API)
#     - The Punk API
#     - The API for Statistics Denmark
# 5. Bonus Exercises $-$ Traffic Data in Copenhagen
#
# *Alternative sources*: If you get lost, you might find [this page](https://pythonprogramming.net/string-concatenation-formatting-intermediate-python-tutorial/) on pythonprogramming.net useful. [This page](https://www.python-course.eu/python3_sequential_data_types.php) also gives an introduction to the basics of strings and their related data types.

# %% [markdown]
# # Part 1: String Operations
#
# As we have already learned, strings are sequential containers of characters. In Python we use two kinds of characters:
# -  American Standard Code (`ascii`)
#     - Characters from English alphabet, numbers, symbols for writing
#     - 8 bit information
#
# - Unicode (`UTF`)
#     - Characters from European and Asian language and much more
#     - 16 bit information
#     - Available in URLs recently, e.g. [møn.dk](https://møn.dk)
#
#
# Note that while unicode is a little more heavy and costs more space, it is way more flexible and we get less errors when importing data from non-ascii languages. This reason is also why Python adopted unicode as standard since the release of Python 3.
#
# To see that strings are sequential containers, see the example below where we slice them like a list or dataframe/array:

# %%
str1 = 'police'
str1[2:]
# Out:
# 'lice'

# %% [markdown]
# ## Common string operations
#
# Strings have multiple operations and functions associated. In this exercise, we investigate a few of these. We also explore the sequence form of a string and how it can be sliced and accessed via indices. In the following, we provide a small tour of some of the most important technical features of strings.

# %% [markdown]
# One thing that can be helpful when working with strings is that you can alter the sentence-case of strings by using the string methods `upper`, `lower`, `capitalize`. Consider the example below and try switching `upper()` with one of the other operations:

# %%
str1.upper()
# Out:
# 'POLICE'

# %% [markdown]
# We can also use the `replace` method to substitute parts of the strings:

# %%
str1.replace('po', 'ma')
# Out:
# 'malice'

# %% [markdown]
# We can also check whether a substring is within a given string and much more. The general syntax is
# ```python
# T in S
# ```
# which checks whether a string `S` contains the substring `T`. We should always get a boolean True/False outcome in return. See two applications below:

# %%
print('ice' in str1, 'mice' in str1)
# Out:
# True False

# %% [markdown]
# Another procedure is to add strings together like below:

# %%
str2 = 'officer'
str1 + ' ' + str2
# Out:
# 'police officer'

# %% [markdown]
# This can be helpful when we want to combine strings of words into sentences or long text files.

# %% [markdown]
# ## More string operations
# In addition to the techniques above, strings are equipped with an array of _methods_, for solving more complex tasks. For example:
# - `str.join(list)` will insert a string in between each element of a list
# - `str.strip()` removes spaces in the beginning and end of a word
# - the f-string fills in specified blanks in a string
# - `str1.split(str2)` splits `str1` into a list through all places where `str2` shows up
#
# Below we illustrate the use of each function:
#
# ```python
# >>> " ".join(['Hello', 'World!'])
# 'Hello World!'
#
# >>> ' Hello World!   '.strip()
# 'Hello World!'
#
# >>> w = 'World'
# >>> f'Hello {w}'
# 'Hello World!'
#
# >>> 'a,b,c'.split(',')
# ['a','b','c']
# ```

# %% [markdown]
# ## Warm-up String Exercises
#
# In the first couple of exercises, you should use the examples above to solve a set of tasks.
#
# > **Ex. 5.1.1**: Let `s1='Chameleon'` and `s2='ham'`. Check whether the string `s2` is a substring of `s1`. Is `'hello'` a substring `'goodbye'`?

# %%
# YOUR CODE HERE

# Given strings
s1 = 'Chameleon'
s2 = 'ham'

# Check whether s2 is a substring of s1
is_substring = s2 in s1
print(f"Is '{s2}' a substring of '{s1}'? {is_substring}")

# Check whether 'hello' is a substring of 'goodbye'
s3 = 'hello'
s4 = 'goodbye'
is_substring_hello = s3 in s4
print(f"Is '{s3}' a substring of '{s4}'? {is_substring_hello}")
# Out:
# Is 'ham' a substring of 'Chameleon'? True
# Is 'hello' a substring of 'goodbye'? False

# %% [markdown]
# > **Ex. 5.1.2**: From the string `s1` select the last four characters. What is the index of the character `a` in `s1`?
#
# > *Hint*: We can selecti a substring by slicing it with the `[]` notation, from the start to end where start is included and end is excluded. Recall that Python has zero-based indexing, see explanation [here](https://softwareengineering.stackexchange.com/questions/110804/why-are-zero-based-arrays-the-norm).

# %%
# YOUR CODE HERE

# Given string
s1 = 'Chameleon'

# Select the last four characters of s1
last_four_characters = s1[-4:]
print("Last four characters:", last_four_characters)

# Find the index of the character 'a' in s1
index_of_a = s1.index('a')
print("Index of 'a' in s1:", index_of_a)
# Out:
# Last four characters: leon
# Index of 'a' in s1: 2

# %% [markdown]
# > **Ex. 5.1.3:** Use the `join()` and `strip()` functions to retrieve the sentence `The quick brown fox jumps over the lazy dog` from the list  `list_of_words` in the code cell below.
#
# > *Hint:* If you want to challenge yourself, see if you can do this in one line with a list comprehension!

# %%
list_of_words = ['       The        ', '   quick   ', '     brown      ',
                 ' fox          ', '          jumps     ', '   over ',
                 '          the   ', '  lazy     ', '          dog     ']

# %%
# YOUR CODE HERE

# Step 1: Use list comprehension to strip each word and filter out empty strings
cleaned_words = [word.strip() for word in list_of_words if word.strip()]

# Step 2: Join the cleaned words with spaces to form the sentence
sentence = ' '.join(cleaned_words)

print(sentence)
# Out:
# The quick brown fox jumps over the lazy dog

# %% [markdown]
# > **Ex. 5.1.4:** Let `l1 = ['r ', 'Is', '>', ' < ', 'g ', '?']`. Create from `l1` the sentence "Is r > g?" using your knowledge about string formatting. Make sure there is only one space in between worlds.
# >
# > _Hint:_ You should be able to combine the above information to solve this exercise.

# %%
# YOUR CODE HERE

l1 = ['r ', 'Is', '>', ' < ', 'g ', '?']

# Create the sentence using string formatting
sentence = '{} {} {} {} {} {}'.format(l1[1], l1[0].strip(), l1[2], l1[4].strip(), l1[3].strip(), l1[5])

print(sentence)
# Out:
# Is r > g < ?

# %% [markdown]
# # Part 2: Saving as Text File
# In this course, we have already seen that we can output tabular data as CSV files. These files are essentially text files with specific structure that allows a computer to identify rows and columns.
#
# In the example below, we will learn how to actually save a string directly as a text file. Note how we make a line break using `\n` - this is a string escape sequence, read more [here](https://docs.python.org/3/reference/lexical_analysis.html#literals).

# %%
my_str = 'This is important...'
my_str2 = 'Written in Python!'
escape_seq = '\n'

with open('my_file.txt', 'w') as f:
    f.write(my_str+escape_seq+my_str2)

# %% [markdown]
# The code below opens the text file and prints the string.

# %%
with open('my_file.txt', 'r') as f:    
    print(f.read())
# Out:
# This is important...
# Written in Python!

# %% [markdown]
# > **Ex. 5.2.1:** Create a .txt file called `to_do_list.txt` with a to-do list by looping over the list `to_do = ['1. Hit the gym', '2. Pay bills', '3. Meet George', '4. Buy eggs', '5. Read a book']` and writing each element on a seperate line.

# %%
to_do = ['1. Hit the gym', '2. Pay bills', '3. Meet George', '4. Buy eggs', '5. Read a book']

# %%
# YOUR CODE HERE

# Open the file in write mode ('w')
with open('to_do_list.txt', 'w') as file:
    # Loop through the to_do list and write each element on a separate line
    for task in to_do:
        file.write(task + '\n')

# %% [markdown]
# Does the file look like you expected?

# %%
with open('to_do_list.txt', 'r') as f:    
    print(f.read())
# Out:
# 1. Hit the gym
# 2. Pay bills
# 3. Meet George
# 4. Buy eggs
# 5. Read a book

# %% [markdown]
# # Part 3: Python Containers and Dictionaries
#
# Dictionaries (or simply `dict`) are a central building block of python. Python dicts are constructed from pairs of keys and values, making them extremely versatile for data storage. Like list, they can contain deep nested structures, e.g. a dict of dicts of lists. You can learn more about this in the following video:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('XeN7RY1MwFM', width=640, height=360)

# %% [markdown]
# Try running the code below, where the keys are strings (names from recent Danish prime ministers) and values are also strings (e.g. political affiliation):

# %%
my_dict1 = {'Anders': "Venstre",
            'Helle': "Socialdemokratiet",
            'Lars': "Venstre",
            'Mette': "Socialdemokratiet"}

# %% [markdown]
# Now,  print the party of some (former) Danish prime minister by replacing `'Name'` below.

# %%
print(my_dict1['Anders'])
# Out:
# Venstre

# %% [markdown]
# > **Ex. 5.3.1**: Create an empty dictionary `words` using the `dict()`function. Then add each of the words in `['animal', 'coffee', 'python', 'unit', 'knowledge', 'tread', 'arise']` as a key, with the value being a boolean indicator for whether the word begins with a vowel. The results should look like `{'bacon': False, 'asynchronous': True ...}`.
#
# > _Hint:_ One approach is to first construct a function that asseses whether a given word begins with a vowel or not.

# %%
# YOUR CODE HERE

def starts_with_vowel(word):
    vowels = ['a', 'e', 'i', 'o', 'u']
    return word[0].lower() in vowels

words_list = ['animal', 'coffee', 'python', 'unit', 'knowledge', 'tread', 'arise']

# Create an empty dictionary
words = dict()

# Loop through the list of words and add them to the dictionary
for word in words_list:
    words[word] = starts_with_vowel(word)

print(words)
# Out:
# {'animal': True, 'coffee': False, 'python': False, 'unit': True, 'knowledge': False, 'tread': False, 'arise': True}

# %% [markdown]
# > **Ex. 5.3.2:** Loop through the dictionary `words`. In each iteration, you should print a proper sentence stating whether the current word begins with a vowel or not.
#
# > _Hint:_ You can loop through both keys and values simultaneously with the `.items()` method. [This](https://www.tutorialspoint.com/python/python_dictionary.htm) and [this](https://stackoverflow.com/questions/3294889/iterating-over-dictionaries-using-for-loops) might help you.

# %%
# YOUR CODE HERE

# Loop through the dictionary and print the sentences
for word, begins_with_vowel in words.items():
    vowel_status = 'does begin with' if begins_with_vowel else 'does not begin with'
    print(f"The word '{word}' {vowel_status} a vowel.")
# Out:
# The word 'animal' does begin with a vowel.
# The word 'coffee' does not begin with a vowel.
# The word 'python' does not begin with a vowel.
# The word 'unit' does begin with a vowel.
# The word 'knowledge' does not begin with a vowel.
# The word 'tread' does not begin with a vowel.
# The word 'arise' does begin with a vowel.

# %% [markdown]
# In the video, we also introduced the popular JSON file format which can store lists and dictionaries and hold the three fundamental data types `float`, `int` and `str`. The code example below uses the JSON module to save our dictionary. We use a trick by first converting the JSON file to a string. This can be done with the function `dumps` in the module `json`:

# %%
import json

with open('my_file.JSON', 'w') as f:
    my_json_str = json.dumps(words) # convert dictonary to string with JSON formatting
    f.write(my_json_str) # write the string to file

with open('my_file.JSON', 'r') as f:
    print(f.read()) # read the string from file
# Out:
# {"animal": true, "coffee": false, "python": false, "unit": true, "knowledge": false, "tread": false, "arise": true}

# %% [markdown]
# > **Ex. 5.3.3:** Install `https://pypi.org/project/Random-Word/` (documentation [here](https://pypi.org/project/Random-Word/)) by typing `pip install random-word` in your *Anaconda prompt*, and then run the line below. Doing so, you should get a list of 100 randomly drawn words. Now, create a dictionary that contains the length of each of these words (i.e. like `{'livering': 8, 'reiterate': 9,...}`) and save it as a json-file called `r_words.JSON`. Then read it and make sure that you got everything right.

# %%
from random_word import RandomWords
r = RandomWords()
r_words = [r.get_random_word() for _ in range(100)]

# %%
# YOUR CODE HERE

# Create a dictionary with the length of each word
word_lengths_dict = {word: len(word) for word in r_words}

# Save the dictionary as a JSON file
with open('r_words.JSON', 'w') as json_file:
    json.dump(word_lengths_dict, json_file)

# Read the JSON file back to verify
with open('r_words.JSON', 'r') as json_file:
    loaded_dict = json.load(json_file)

# Print the loaded dictionary to verify
loaded_dict
# Out:
# {'urobenzoic': 10,
#  'eventful': 8,
#  'ukulele': 7,
#  'minkopi': 7,
#  'radiators': 9,
#  'barony': 6,
#  'lithonephritis': 14,
#  'nonapproachabness': 17,
#  'brigadier': 9,
#  'awaken': 6,
#  'rejumble': 8,
#  'preprimary': 10,
#  'fishworker': 10,
#  'kidders': 7,
#  'pockets': 7,
#  'nonsuspended': 12,
#  'flume': 5,
#  'recabling': 9,
#  'repetitionary': 13,
#  'olacad': 6,
#  'hoodoes': 7,
#  'anomouran': 9,
#  'sidalcea': 8,
#  'anthems': 7,
#  'abolitionist': 12,
#  'marage': 6,
#  'impersonation': 13,
#  'uncaria': 7,
#  'thoracicolumbar': 15,
#  'unkindlily': 10,
#  'fadingly': 8,
#  'naiadaceous': 11,
#  'rogueries': 9,
#  'sphyrapicus': 11,
#  'quantivalent': 12,
#  'kotowed': 7,
#  'coliander': 9,
#  'blackhearted': 12,
#  'quicksandy': 10,
#  'gortonite': 9,
#  'chivy': 5,
#  'disturnpike': 11,
#  'paga': 4,
#  'edwardian': 9,
#  'teleprocessing': 14,
#  'utterable': 9,
#  'outlander': 9,
#  'dishfuls': 8,
#  'stipellate': 10,
#  'anallagmatis': 12,
#  'lykewake': 8,
#  'gorgoniacean': 12,
#  'jadishly': 8,
#  'trenching': 9,
#  'warsles': 7,
#  'deciares': 8,
#  'bronchography': 13,
#  'unmullioned': 11,
#  'reavail': 7,
#  'zooter': 6,
#  'mycetomatous': 12,
#  'monseignevr': 11,
#  'subdivecious': 12,
#  'haverels': 8,
#  'ruttily': 7,
#  'becoward': 8,
#  'allurance': 9,
#  'frontlet': 8,
#  'unappreciating': 14,
#  'sobbing': 7,
#  'gasbag': 6,
#  'amyloleucite': 12,
#  'gyrus': 5,
#  'halakoth': 8,
#  'endocrinological': 16,
#  'monasticize': 11,
#  'refect': 6,
#  'whelphood': 9,
#  'afterstrain': 11,
#  'remarshal': 9,
#  'endoconidia': 11,
#  'cliques': 7,
#  'snecked': 7,
#  'wlench': 6,
#  'promammalian': 12,
#  'empoison': 8,
#  'rezoned': 7,
#  'monarchlike': 11,
#  'whirlicote': 10,
#  'passeres': 8,
#  'steelhead': 9,
#  'infantly': 8,
#  'ungt': 4,
#  'haikai': 6,
#  'makers': 6,
#  'kersey': 6,
#  'normated': 8,
#  'contractation': 13,
#  'troffer': 7,
#  'latifundium': 11}

# %% [markdown]
# <br>
#
# # Part 4: Python and the Web
#
# The internet is a massive source for collecting data. Watch the video below to get an overview of the most fundamental protocols and how we work with them.

# %%
YouTubeVideo('D6FFt0z8pFc', width=640, height=360)

# %% [markdown]
# ## Application Programming Interface (API)
#
# APIs are protocols that allow us to request information and/or services from the provider of the API. In this course, we are mainly interested in APIs that provide data as a response to our requests. Watch the video below to get a sense of what APIs exist and how they work.

# %%
YouTubeVideo('PvMIubOCUD8', width=640, height=360)

# %% [markdown]
# ## Building the Queries
# We will now move on to understanding how we can interact with a web API in Python. First we will see how to build a query, which is simply a web address. By typing in a specific web address, the web server will receive information from us.
#
# In the example below we build a URL that allows us to check out which repositories ISDSUCPH has publicly available.

# %%
server_url = 'https://api.github.com'
endpoint_path = '/users/isdsucph/repos'

url = server_url + endpoint_path

print(url)
# Out:
# https://api.github.com/users/isdsucph/repos

# %% [markdown]
# ## Sending the Query
# Python has a smart module, named `requests` (get it with `pip install requests`), that allows us to interact with the web. When we request a URL, we get a response in return. Among other things, it allows us to inspect the HTML code. In the example below, we query the URL for the GitHub API we made above.

# %%
import requests # import the module requests
response = requests.get(url) # submit query with `get` and save response as object

# %% [markdown]
# When we examine the response, we can see the HTML string is pretty long, so we limit the initial output to the first 1,000 characters.

# %%
print(len(response.text),'\n') # print length of HTML
print(response.text[:1000]) # print first 1,000 characters of HTML
# Out:
# 20456
#
# [{"id":381957904,"node_id":"MDEwOlJlcG9zaXRvcnkzODE5NTc5MDQ=","name":"isds2021","full_name":"isdsucph/isds2021","private":false,"owner":{"login":"isdsucph","id":86770179,"node_id":"MDQ6VXNlcjg2NzcwMTc5","avatar_url":"https://avatars.githubusercontent.com/u/86770179?v=4","gravatar_id":"","url":"https://api.github.com/users/isdsucph","html_url":"https://github.com/isdsucph","followers_url":"https://api.github.com/users/isdsucph/followers","following_url":"https://api.github.com/users/isdsucph/following{/other_user}","gists_url":"https://api.github.com/users/isdsucph/gists{/gist_id}","starred_url":"https://api.github.com/users/isdsucph/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/isdsucph/subscriptions","organizations_url":"https://api.github.com/users/isdsucph/orgs","repos_url":"https://api.github.com/users/isdsucph/repos","events_url":"https://api.github.com/users/isdsucph/events{/privacy}","received_events_url":"https://api.github.com/users/isdsucph/receive

# %% [markdown]
# Looking closely, we notice how the structure resembles lists and dictionaries (note that depending on the context, these responses can be VERY difficult to make sense of from simply printing - just as in this case). Therefore, we try to convert it by assuming that it is structured as JSON.

# %%
response_json = response.json() # convert response to a list of dicts
response_json[0]
# Out:
# {'id': 381957904,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkzODE5NTc5MDQ=',
#  'name': 'isds2021',
#  'full_name': 'isdsucph/isds2021',
#  'private': False,
#  'owner': {'login': 'isdsucph',
#   'id': 86770179,
#   'node_id': 'MDQ6VXNlcjg2NzcwMTc5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/86770179?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/isdsucph',
#   'html_url': 'https://github.com/isdsucph',
#   'followers_url': 'https://api.github.com/users/isdsucph/followers',
#   'following_url': 'https://api.github.com/users/isdsucph/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/isdsucph/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/isdsucph/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/isdsucph/subscriptions',
#   'organizations_url': 'https://api.github.com/users/isdsucph/orgs',
#   'repos_url': 'https://api.github.com/users/isdsucph/repos',
#   'events_url': 'https://api.github.com/users/isdsucph/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/isdsucph/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'html_url': 'https://github.com/isdsucph/isds2021',
#  'description': 'Introduction to Social Data Science 2021 - a summer school course https://isdsucph.github.io/isds2021/',
#  'fork': False,
#  'url': 'https://api.github.com/repos/isdsucph/isds2021',
#  'forks_url': 'https://api.github.com/repos/isdsucph/isds2021/forks',
#  'keys_url': 'https://api.github.com/repos/isdsucph/isds2021/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/isdsucph/isds2021/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/isdsucph/isds2021/teams',
#  'hooks_url': 'https://api.github.com/repos/isdsucph/isds2021/hooks',
#  'issue_events_url': 'https://api.github.com/repos/isdsucph/isds2021/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/isdsucph/isds2021/events',
#  'assignees_url': 'https://api.github.com/repos/isdsucph/isds2021/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/isdsucph/isds2021/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/isdsucph/isds2021/tags',
#  'blobs_url': 'https://api.github.com/repos/isdsucph/isds2021/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/isdsucph/isds2021/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/isdsucph/isds2021/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/isdsucph/isds2021/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/isdsucph/isds2021/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/isdsucph/isds2021/languages',
#  'stargazers_url': 'https://api.github.com/repos/isdsucph/isds2021/stargazers',
#  'contributors_url': 'https://api.github.com/repos/isdsucph/isds2021/contributors',
#  'subscribers_url': 'https://api.github.com/repos/isdsucph/isds2021/subscribers',
#  'subscription_url': 'https://api.github.com/repos/isdsucph/isds2021/subscription',
#  'commits_url': 'https://api.github.com/repos/isdsucph/isds2021/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/isdsucph/isds2021/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/isdsucph/isds2021/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/isdsucph/isds2021/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/isdsucph/isds2021/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/isdsucph/isds2021/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/isdsucph/isds2021/merges',
#  'archive_url': 'https://api.github.com/repos/isdsucph/isds2021/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/isdsucph/isds2021/downloads',
#  'issues_url': 'https://api.github.com/repos/isdsucph/isds2021/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/isdsucph/isds2021/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/isdsucph/isds2021/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/isdsucph/isds2021/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/isdsucph/isds2021/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/isdsucph/isds2021/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/isdsucph/isds2021/deployments',
#  'created_at': '2021-07-01T08:09:57Z',
#  'updated_at': '2022-12-28T14:54:23Z',
#  'pushed_at': '2021-08-23T08:48:57Z',
#  'git_url': 'git://github.com/isdsucph/isds2021.git',
#  'ssh_url': 'git@github.com:isdsucph/isds2021.git',
#  'clone_url': 'https://github.com/isdsucph/isds2021.git',
#  'svn_url': 'https://github.com/isdsucph/isds2021',
#  'homepage': '',
#  'size': 66010,
#  'stargazers_count': 22,
#  'watchers_count': 22,
#  'language': 'Jupyter Notebook',
#  'has_issues': True,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': True,
#  'has_pages': True,
#  'has_discussions': False,
#  'forks_count': 38,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 11,
#  'license': {'key': 'mit',
#   'name': 'MIT License',
#   'spdx_id': 'MIT',
#   'url': 'https://api.github.com/licenses/mit',
#   'node_id': 'MDc6TGljZW5zZTEz'},
#  'allow_forking': True,
#  'is_template': False,
#  'web_commit_signoff_required': False,
#  'topics': [],
#  'visibility': 'public',
#  'forks': 38,
#  'open_issues': 11,
#  'watchers': 22,
#  'default_branch': 'main'}

# %% [markdown]
# Now it is easier to see that this is in fact a dictionary. Looking more closely at the output, we can also see that the depth of the dictionary is not trivial - it contains dictionaries of dictionaries.
#
# In order to make the output more digestable, use the so-called *pretty printer* that, among other things, arranges the output alphabetically and makes the depth of the output more clearly visible. Take a look and compare with what we had above:

# %%
import pprint #Data pretty printer
pprint.pprint(response.json()) #Everything is aranged alphabetically and in appropriate levels
# Out:
# [{'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/isdsucph/isds2021/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/isdsucph/isds2021/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/isdsucph/isds2021/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/isdsucph/isds2021/branches{/branch}',
#   'clone_url': 'https://github.com/isdsucph/isds2021.git',
#   'collaborators_url': 'https://api.github.com/repos/isdsucph/isds2021/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/isdsucph/isds2021/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/isdsucph/isds2021/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/isdsucph/isds2021/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/isdsucph/isds2021/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/isdsucph/isds2021/contributors',
#   'created_at': '2021-07-01T08:09:57Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/isdsucph/isds2021/deployments',
#   'description': 'Introduction to Social Data Science 2021 - a summer school '
#                  'course https://isdsucph.github.io/isds2021/',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/isdsucph/isds2021/downloads',
#   'events_url': 'https://api.github.com/repos/isdsucph/isds2021/events',
#   'fork': False,
#   'forks': 38,
#   'forks_count': 38,
#   'forks_url': 'https://api.github.com/repos/isdsucph/isds2021/forks',
#   'full_name': 'isdsucph/isds2021',
#   'git_commits_url': 'https://api.github.com/repos/isdsucph/isds2021/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/isdsucph/isds2021/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/isdsucph/isds2021/git/tags{/sha}',
#   'git_url': 'git://github.com/isdsucph/isds2021.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/isdsucph/isds2021/hooks',
#   'html_url': 'https://github.com/isdsucph/isds2021',
#   'id': 381957904,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/isdsucph/isds2021/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/isdsucph/isds2021/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/isdsucph/isds2021/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/isdsucph/isds2021/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/isdsucph/isds2021/labels{/name}',
#   'language': 'Jupyter Notebook',
#   'languages_url': 'https://api.github.com/repos/isdsucph/isds2021/languages',
#   'license': {'key': 'mit',
#               'name': 'MIT License',
#               'node_id': 'MDc6TGljZW5zZTEz',
#               'spdx_id': 'MIT',
#               'url': 'https://api.github.com/licenses/mit'},
#   'merges_url': 'https://api.github.com/repos/isdsucph/isds2021/merges',
#   'milestones_url': 'https://api.github.com/repos/isdsucph/isds2021/milestones{/number}',
#   'mirror_url': None,
#   'name': 'isds2021',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzODE5NTc5MDQ=',
#   'notifications_url': 'https://api.github.com/repos/isdsucph/isds2021/notifications{?since,all,participating}',
#   'open_issues': 11,
#   'open_issues_count': 11,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/86770179?v=4',
#             'events_url': 'https://api.github.com/users/isdsucph/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/isdsucph/followers',
#             'following_url': 'https://api.github.com/users/isdsucph/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/isdsucph/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/isdsucph',
#             'id': 86770179,
#             'login': 'isdsucph',
#             'node_id': 'MDQ6VXNlcjg2NzcwMTc5',
#             'organizations_url': 'https://api.github.com/users/isdsucph/orgs',
#             'received_events_url': 'https://api.github.com/users/isdsucph/received_events',
#             'repos_url': 'https://api.github.com/users/isdsucph/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/isdsucph/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/isdsucph/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/isdsucph'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/isdsucph/isds2021/pulls{/number}',
#   'pushed_at': '2021-08-23T08:48:57Z',
#   'releases_url': 'https://api.github.com/repos/isdsucph/isds2021/releases{/id}',
#   'size': 66010,
#   'ssh_url': 'git@github.com:isdsucph/isds2021.git',
#   'stargazers_count': 22,
#   'stargazers_url': 'https://api.github.com/repos/isdsucph/isds2021/stargazers',
#   'statuses_url': 'https://api.github.com/repos/isdsucph/isds2021/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/isdsucph/isds2021/subscribers',
#   'subscription_url': 'https://api.github.com/repos/isdsucph/isds2021/subscription',
#   'svn_url': 'https://github.com/isdsucph/isds2021',
#   'tags_url': 'https://api.github.com/repos/isdsucph/isds2021/tags',
#   'teams_url': 'https://api.github.com/repos/isdsucph/isds2021/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/isdsucph/isds2021/git/trees{/sha}',
#   'updated_at': '2022-12-28T14:54:23Z',
#   'url': 'https://api.github.com/repos/isdsucph/isds2021',
#   'visibility': 'public',
#   'watchers': 22,
#   'watchers_count': 22,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/isdsucph/isds2022/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/isdsucph/isds2022/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/isdsucph/isds2022/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/isdsucph/isds2022/branches{/branch}',
#   'clone_url': 'https://github.com/isdsucph/isds2022.git',
#   'collaborators_url': 'https://api.github.com/repos/isdsucph/isds2022/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/isdsucph/isds2022/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/isdsucph/isds2022/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/isdsucph/isds2022/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/isdsucph/isds2022/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/isdsucph/isds2022/contributors',
#   'created_at': '2022-06-17T09:49:06Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/isdsucph/isds2022/deployments',
#   'description': 'Introduction to Social Data Science 2022 - a summer school '
#                  'course https://isdsucph.github.io/isds2022/',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/isdsucph/isds2022/downloads',
#   'events_url': 'https://api.github.com/repos/isdsucph/isds2022/events',
#   'fork': False,
#   'forks': 23,
#   'forks_count': 23,
#   'forks_url': 'https://api.github.com/repos/isdsucph/isds2022/forks',
#   'full_name': 'isdsucph/isds2022',
#   'git_commits_url': 'https://api.github.com/repos/isdsucph/isds2022/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/isdsucph/isds2022/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/isdsucph/isds2022/git/tags{/sha}',
#   'git_url': 'git://github.com/isdsucph/isds2022.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/isdsucph/isds2022/hooks',
#   'html_url': 'https://github.com/isdsucph/isds2022',
#   'id': 504478840,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/isdsucph/isds2022/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/isdsucph/isds2022/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/isdsucph/isds2022/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/isdsucph/isds2022/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/isdsucph/isds2022/labels{/name}',
#   'language': 'Jupyter Notebook',
#   'languages_url': 'https://api.github.com/repos/isdsucph/isds2022/languages',
#   'license': {'key': 'mit',
#               'name': 'MIT License',
#               'node_id': 'MDc6TGljZW5zZTEz',
#               'spdx_id': 'MIT',
#               'url': 'https://api.github.com/licenses/mit'},
#   'merges_url': 'https://api.github.com/repos/isdsucph/isds2022/merges',
#   'milestones_url': 'https://api.github.com/repos/isdsucph/isds2022/milestones{/number}',
#   'mirror_url': None,
#   'name': 'isds2022',
#   'node_id': 'R_kgDOHhG8eA',
#   'notifications_url': 'https://api.github.com/repos/isdsucph/isds2022/notifications{?since,all,participating}',
#   'open_issues': 22,
#   'open_issues_count': 22,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/86770179?v=4',
#             'events_url': 'https://api.github.com/users/isdsucph/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/isdsucph/followers',
#             'following_url': 'https://api.github.com/users/isdsucph/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/isdsucph/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/isdsucph',
#             'id': 86770179,
#             'login': 'isdsucph',
#             'node_id': 'MDQ6VXNlcjg2NzcwMTc5',
#             'organizations_url': 'https://api.github.com/users/isdsucph/orgs',
#             'received_events_url': 'https://api.github.com/users/isdsucph/received_events',
#             'repos_url': 'https://api.github.com/users/isdsucph/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/isdsucph/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/isdsucph/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/isdsucph'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/isdsucph/isds2022/pulls{/number}',
#   'pushed_at': '2022-08-12T14:18:40Z',
#   'releases_url': 'https://api.github.com/repos/isdsucph/isds2022/releases{/id}',
#   'size': 50503,
#   'ssh_url': 'git@github.com:isdsucph/isds2022.git',
#   'stargazers_count': 21,
#   'stargazers_url': 'https://api.github.com/repos/isdsucph/isds2022/stargazers',
#   'statuses_url': 'https://api.github.com/repos/isdsucph/isds2022/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/isdsucph/isds2022/subscribers',
#   'subscription_url': 'https://api.github.com/repos/isdsucph/isds2022/subscription',
#   'svn_url': 'https://github.com/isdsucph/isds2022',
#   'tags_url': 'https://api.github.com/repos/isdsucph/isds2022/tags',
#   'teams_url': 'https://api.github.com/repos/isdsucph/isds2022/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/isdsucph/isds2022/git/trees{/sha}',
#   'updated_at': '2023-03-18T17:05:01Z',
#   'url': 'https://api.github.com/repos/isdsucph/isds2022',
#   'visibility': 'public',
#   'watchers': 21,
#   'watchers_count': 21,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/isdsucph/isds2023/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/isdsucph/isds2023/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/isdsucph/isds2023/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/isdsucph/isds2023/branches{/branch}',
#   'clone_url': 'https://github.com/isdsucph/isds2023.git',
#   'collaborators_url': 'https://api.github.com/repos/isdsucph/isds2023/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/isdsucph/isds2023/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/isdsucph/isds2023/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/isdsucph/isds2023/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/isdsucph/isds2023/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/isdsucph/isds2023/contributors',
#   'created_at': '2023-06-24T20:02:00Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/isdsucph/isds2023/deployments',
#   'description': 'Introduction to Social Data Science 2023 - a summer school '
#                  'course https://isdsucph.github.io/isds2023/',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/isdsucph/isds2023/downloads',
#   'events_url': 'https://api.github.com/repos/isdsucph/isds2023/events',
#   'fork': False,
#   'forks': 9,
#   'forks_count': 9,
#   'forks_url': 'https://api.github.com/repos/isdsucph/isds2023/forks',
#   'full_name': 'isdsucph/isds2023',
#   'git_commits_url': 'https://api.github.com/repos/isdsucph/isds2023/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/isdsucph/isds2023/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/isdsucph/isds2023/git/tags{/sha}',
#   'git_url': 'git://github.com/isdsucph/isds2023.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': False,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/isdsucph/isds2023/hooks',
#   'html_url': 'https://github.com/isdsucph/isds2023',
#   'id': 658111812,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/isdsucph/isds2023/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/isdsucph/isds2023/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/isdsucph/isds2023/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/isdsucph/isds2023/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/isdsucph/isds2023/labels{/name}',
#   'language': 'Jupyter Notebook',
#   'languages_url': 'https://api.github.com/repos/isdsucph/isds2023/languages',
#   'license': {'key': 'mit',
#               'name': 'MIT License',
#               'node_id': 'MDc6TGljZW5zZTEz',
#               'spdx_id': 'MIT',
#               'url': 'https://api.github.com/licenses/mit'},
#   'merges_url': 'https://api.github.com/repos/isdsucph/isds2023/merges',
#   'milestones_url': 'https://api.github.com/repos/isdsucph/isds2023/milestones{/number}',
#   'mirror_url': None,
#   'name': 'isds2023',
#   'node_id': 'R_kgDOJzn9RA',
#   'notifications_url': 'https://api.github.com/repos/isdsucph/isds2023/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/86770179?v=4',
#             'events_url': 'https://api.github.com/users/isdsucph/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/isdsucph/followers',
#             'following_url': 'https://api.github.com/users/isdsucph/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/isdsucph/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/isdsucph',
#             'id': 86770179,
#             'login': 'isdsucph',
#             'node_id': 'MDQ6VXNlcjg2NzcwMTc5',
#             'organizations_url': 'https://api.github.com/users/isdsucph/orgs',
#             'received_events_url': 'https://api.github.com/users/isdsucph/received_events',
#             'repos_url': 'https://api.github.com/users/isdsucph/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/isdsucph/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/isdsucph/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/isdsucph'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/isdsucph/isds2023/pulls{/number}',
#   'pushed_at': '2023-08-02T06:53:42Z',
#   'releases_url': 'https://api.github.com/repos/isdsucph/isds2023/releases{/id}',
#   'size': 16729,
#   'ssh_url': 'git@github.com:isdsucph/isds2023.git',
#   'stargazers_count': 17,
#   'stargazers_url': 'https://api.github.com/repos/isdsucph/isds2023/stargazers',
#   'statuses_url': 'https://api.github.com/repos/isdsucph/isds2023/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/isdsucph/isds2023/subscribers',
#   'subscription_url': 'https://api.github.com/repos/isdsucph/isds2023/subscription',
#   'svn_url': 'https://github.com/isdsucph/isds2023',
#   'tags_url': 'https://api.github.com/repos/isdsucph/isds2023/tags',
#   'teams_url': 'https://api.github.com/repos/isdsucph/isds2023/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/isdsucph/isds2023/git/trees{/sha}',
#   'updated_at': '2023-08-02T11:58:00Z',
#   'url': 'https://api.github.com/repos/isdsucph/isds2023',
#   'visibility': 'public',
#   'watchers': 17,
#   'watchers_count': 17,
#   'web_commit_signoff_required': False},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/branches{/branch}',
#   'clone_url': 'https://github.com/isdsucph/isdsucph.github.io.git',
#   'collaborators_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/contributors',
#   'created_at': '2021-07-01T08:13:49Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/downloads',
#   'events_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/forks',
#   'full_name': 'isdsucph/isdsucph.github.io',
#   'git_commits_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/git/tags{/sha}',
#   'git_url': 'git://github.com/isdsucph/isdsucph.github.io.git',
#   'has_discussions': False,
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/hooks',
#   'html_url': 'https://github.com/isdsucph/isdsucph.github.io',
#   'id': 381958923,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/merges',
#   'milestones_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/milestones{/number}',
#   'mirror_url': None,
#   'name': 'isdsucph.github.io',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzODE5NTg5MjM=',
#   'notifications_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/86770179?v=4',
#             'events_url': 'https://api.github.com/users/isdsucph/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/isdsucph/followers',
#             'following_url': 'https://api.github.com/users/isdsucph/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/isdsucph/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/isdsucph',
#             'id': 86770179,
#             'login': 'isdsucph',
#             'node_id': 'MDQ6VXNlcjg2NzcwMTc5',
#             'organizations_url': 'https://api.github.com/users/isdsucph/orgs',
#             'received_events_url': 'https://api.github.com/users/isdsucph/received_events',
#             'repos_url': 'https://api.github.com/users/isdsucph/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/isdsucph/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/isdsucph/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/isdsucph'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/pulls{/number}',
#   'pushed_at': '2021-07-01T08:13:50Z',
#   'releases_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/releases{/id}',
#   'size': 0,
#   'ssh_url': 'git@github.com:isdsucph/isdsucph.github.io.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/stargazers',
#   'statuses_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/subscribers',
#   'subscription_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/subscription',
#   'svn_url': 'https://github.com/isdsucph/isdsucph.github.io',
#   'tags_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/tags',
#   'teams_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io/git/trees{/sha}',
#   'updated_at': '2021-07-01T08:13:53Z',
#   'url': 'https://api.github.com/repos/isdsucph/isdsucph.github.io',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0,
#   'web_commit_signoff_required': False}]

# %% [markdown]
# ## The Punk API
#
# Now, it is time for you to request information through an API. First, we will work with the punk API that contains information on a large selection of beers. In this part of exercises, you are going to navigate in the information on these beers. Second, you are going to extract information from the DST (Statistics Denmark) API.
#
# The [punk API](https://punkapi.com/) serves information about _beers_. It is a well made and well documented API which makes it great for learning about APIs.
#
# > **Ex. 5.4.1:** Read the documentation on the Punk API available [here](https://punkapi.com/documentation/v2). What is the server url (i.e. root endpoint) of the Punk API? Does it require authentication? Then use the Punk API to make a request for the first 80 beers brewed after April, 2004 with an ABV of at least 5.

# %%
# YOUR CODE HERE

# API base URL
base_url = 'https://api.punkapi.com/v2/'

# Parameters for the request
params = {
    'brewed_after': '04-2004',
    'abv_gt': 5,
    'per_page': 80
}

# Send the GET request to the API endpoint
response = requests.get(base_url + 'beers', params=params)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Get the JSON data from the response
    beers_data = response.json()

    # Now you can work with the beers_data, which contains the information about the beers
    # For example, you can print the names of the beers
    for beer in beers_data:
        print(beer['name'])
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# Pilsen Lager
# Avery Brown Dredge
# Electric India
# AB:12
# AB:07
# Bramling X
# Misspent Youth
# Arcade Nation
# Mixtape 8
# Libertine Porter
# AB:06
# Russian Doll – India Pale Ale
# Hello My Name Is Mette-Marit
# Rabiator
# Devine Rebel (w/ Mikkeller)
# Storm
# The End Of History
# Dog B
# HBC 369
# 10 Heads High
# Dana - IPA Is Dead
# AB:05
# Sorachi Ace
# Bourbon Baby
# Shipwrecker Circus (w/ Oskar Blues)
# Zephyr
# Belgian Trappist
# Kohatu - IPA Is Dead
# Hello My Name is Vladimir
# AB:17
# Hardcore IPA
# Dog Wired (w/8 Wired)
# Anarchist Alchemist
# AB:15
# Goldings - IPA Is Dead
# AB:14
# Lost Dog (w/Lost Abbey)
# TM10
# Paradox Islay
# Albino Squid Assasin
# Amarillo - IPA Is Dead
# Black Eyed King Imp
# Prototype 27
# Coffee Imperial Stout
# Mandarina Bavaria - IPA Is Dead
# Dogma
# AB:08
# Sunk Punk
# Sub Hop
# Tokyo Rising Sun - Lowland
# Hunter Foundation Pale Ale
# AB:16
# Sunmaid Stout
# Whisky Sour - B-Sides
# Black Eyed King Imp - Vietnamese Coffee Edition
# Never Mind The Anabolics
# #Mashtag 2013
# AB:18
# Hops Kill Nazis
# AB:04
# Hopped-Up Brown Ale - Prototype Challenge
# Comet
# Original Dogma (Née Speedball)
# Bavarian Weizen
# Citra
# #Mashtag 2015
# AB:09
# Mango Gose - B-Sides
# Everday Anarchy
# Lumberjack Stout
# Bowman's Beard - B-Sides
# Pumpkin King
# Hello My Name Is Päivi
# Elvis Juice V2.0 - Prototype Challenge
# Riptide
# Peach Therapy
# Clown King
# India Pale Weizen (w/ Weihenstephan)
# Hello My Name Is Beastie
# Punk IPA 2010 - Current

# %% [markdown]
# > **Ex. 5.4.2:** What object type is the API's JSON response? What about the individual items in the container? Convert the response object to a suitable format and answer the following questions:
# > 1) How many beers are there in the JSON object?
# >
# > 2) Print the response with and without the pretty printer. See any difference?
# >
# > 3) Now print only the names of the beers in the JSON object using lower case characters.
# >
# > 4) Select the beer called Rabiator from the JSON object. What is the suggested food pairing?
# >
# > 5) Select the beer called Hello My Name Is Beastie from the JSON object. Which malt ingredients does the Hello My Name Is Beastie contain?

# %%
# YOUR CODE HERE


# 1) How many beers are there in the JSON object?
num_beers = len(beers_data)
print(f"1) Number of beers in the JSON object: {num_beers}")

# 2) Print the response with and without the pretty printer. See any difference?
print("\n2) JSON response with pretty printer:")
pprint.pprint(beers_data)
print("\nJSON response without pretty printer:")
print(beers_data)

# 3) Now print only the names of the beers in the JSON object using lower case characters.
print("\n3) Names of the beers in lower case:")
for beer in beers_data:
    print(beer['name'].lower())

# 4) Select the beer called Rabiator from the JSON object. What is the suggested food pairing?
rabiator = next((beer for beer in beers_data if beer['name'] == 'Rabiator'), None)
if rabiator:
    print("\n4) Suggested food pairing for Rabiator:")
    pprint.pprint(rabiator['food_pairing'])


# 5) Select the beer called Hello My Name Is Beastie from the JSON object. Which malt ingredients does the Hello My Name Is Beastie contain?
hello_beastie = next((beer for beer in beers_data if beer['name'] == 'Hello My Name Is Beastie'), None)
if hello_beastie:
    print("\n5) Malt ingredients for Hello My Name Is Beastie:")
    pprint.pprint(hello_beastie['ingredients']['malt'])
# Out:
# 1) Number of beers in the JSON object: 80
#
# 2) JSON response with pretty printer:
# [{'abv': 6.3,
#   'attenuation_level': 80,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'Play around with the fermentation temperature to get the '
#                   'best flavour profile from the individual yeasts.',
#   'contributed_by': 'Ali Skinner <AliSkinner>',
#   'description': 'Our Unleash the Yeast series was an epic experiment into the '
#                  'differences in aroma and flavour provided by switching up '
#                  'your yeast. We brewed up a wort with a light caramel note '
#                  'and some toasty biscuit flavour, and hopped it with Amarillo '
#                  'and Centennial for a citrusy bitterness. Everything else is '
#                  'down to the yeast. Pilsner yeast ferments with no fruity '
#                  'esters or spicy phenols, although it can add a hint of '
#                  'butterscotch.',
#   'ebc': 30,
#   'first_brewed': '09/2013',
#   'food_pairing': ['Spicy crab cakes',
#                    'Spicy cucumber and carrot Thai salad',
#                    'Sweet filled dumplings'],
#   'ibu': 55,
#   'id': 4,
#   'image_url': 'https://images.punkapi.com/v2/4.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 5},
#                             'attribute': 'bitter',
#                             'name': 'Centennial'},
#                            {'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 5},
#                             'attribute': 'bitter',
#                             'name': 'Amarillo'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 10},
#                             'attribute': 'flavour',
#                             'name': 'Centennial'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 10},
#                             'attribute': 'flavour',
#                             'name': 'Amarillo'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 17.5},
#                             'attribute': 'flavour',
#                             'name': 'Centennial'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 17.5},
#                             'attribute': 'flavour',
#                             'name': 'Amarillo'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 4.58},
#                             'name': 'Extra Pale'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.25},
#                             'name': 'Caramalt'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.06},
#                             'name': 'Dark Crystal'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.25},
#                             'name': 'Munich'}],
#                   'yeast': 'Wyeast 2007 - Pilsen Lager™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 9}},
#              'mash_temp': [{'duration': None,
#                             'temp': {'unit': 'celsius', 'value': 65}}],
#              'twist': None},
#   'name': 'Pilsen Lager',
#   'ph': 4.4,
#   'srm': 15,
#   'tagline': 'Unleash the Yeast Series.',
#   'target_fg': 1012,
#   'target_og': 1060,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 7.2,
#   'attenuation_level': 67,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'Make sure you have a big enough yeast starter to ferment '
#                   'through the OG and lager successfully.',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': 'An Imperial Pilsner in collaboration with beer writers. '
#                  'Tradition. Homage. Revolution. We wanted to showcase the '
#                  'awesome backbone of the Czech brewing tradition, the noble '
#                  'Saaz hop, and also tip our hats to the modern beers that '
#                  'rock our world, and the people who make them.',
#   'ebc': 10,
#   'first_brewed': '02/2011',
#   'food_pairing': ['Vietnamese squid salad',
#                    'Chargrilled corn on the cob with paprika butter',
#                    'Strawberry and rhubarb pie'],
#   'ibu': 59,
#   'id': 5,
#   'image_url': 'https://images.punkapi.com/v2/5.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 60},
#                             'attribute': 'bitter',
#                             'name': 'Saaz'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 60},
#                             'attribute': 'flavour',
#                             'name': 'Saaz'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 60},
#                             'attribute': 'flavour',
#                             'name': 'Saaz'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 6.63},
#                             'name': 'Lager Malt'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.38},
#                             'name': 'Wheat'}],
#                   'yeast': 'Wyeast 2007 - Pilsen Lager™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 10}},
#              'mash_temp': [{'duration': 70,
#                             'temp': {'unit': 'celsius', 'value': 66}}],
#              'twist': None},
#   'name': 'Avery Brown Dredge',
#   'ph': 4.4,
#   'srm': 5,
#   'tagline': "Bloggers' Imperial Pilsner.",
#   'target_fg': 1027,
#   'target_og': 1069,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 5.2,
#   'attenuation_level': 88.9,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'Source some really good heather honey to get the right '
#                   'spicy esters in the beer.',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': 'Re-brewed as a spring seasonal, this beer – which appeared '
#                  'originally as an Equity Punk shareholder creation – retains '
#                  'its trademark spicy, fruity edge. A perfect blend of Belgian '
#                  'Saison and US IPA, crushed peppercorns and heather honey are '
#                  'also added to produce a genuinely unique beer.',
#   'ebc': 15,
#   'first_brewed': '05/2013',
#   'food_pairing': ['Mussels with a garlic and herb sauce',
#                    'Crab melt sandwich',
#                    'Shortbread cookies'],
#   'ibu': 38,
#   'id': 6,
#   'image_url': 'https://images.punkapi.com/v2/6.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 2.5},
#                             'attribute': 'bitter',
#                             'name': 'Amarillo'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 5},
#                             'attribute': 'flavour',
#                             'name': 'Nelson Sauvin'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 5},
#                             'attribute': 'flavour',
#                             'name': 'Amarillo'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 2.5},
#                             'attribute': 'flavour',
#                             'name': 'Peppercorns'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 20},
#                             'attribute': 'flavour',
#                             'name': 'Nelson Sauvin'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Amarillo'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 3.63},
#                             'name': 'Extra Pale'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.13},
#                             'name': 'Munich'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.25},
#                             'name': 'Wheat'}],
#                   'yeast': 'Wyeast 3711 - French Saison™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 22}},
#              'mash_temp': [{'duration': 75,
#                             'temp': {'unit': 'celsius', 'value': 65}}],
#              'twist': 'Honey: 62.5g at End (WP), Coriander Seeds: 8.5g at '
#                       '45mins'},
#   'name': 'Electric India',
#   'ph': 4.4,
#   'srm': 7.5,
#   'tagline': 'Vibrant Hoppy Saison.',
#   'target_fg': 1005,
#   'target_og': 1045,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 11.2,
#   'attenuation_level': 84,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': "Don't worry too much about controlling the temperature with "
#                   "the Belgian yeast strain - just make sure it doesn't rise "
#                   'above 30°C!',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': 'An Imperial Black Belgian Ale aged in old Invergordon Scotch '
#                  'whisky barrels with mountains of raspberries, tayberries and '
#                  'blackberries in each cask. Decadent but light and dry, this '
#                  'beer would make a fantastic base for ageing on pretty much '
#                  'any dark fruit - we used raspberries, tayberries and '
#                  'blackberries beause they were local.',
#   'ebc': 80,
#   'first_brewed': '07/2012',
#   'food_pairing': ['Tandoori lamb with pomegranate',
#                    'Beef Wellington with a red wine jus',
#                    'Raspberry chocolate torte'],
#   'ibu': 35,
#   'id': 7,
#   'image_url': 'https://images.punkapi.com/v2/7.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 31.25},
#                             'attribute': 'bitter',
#                             'name': 'Tomahawk'},
#                            {'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'bitter',
#                             'name': 'Magnum'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Magnum'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Tomahawk'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'flavour',
#                             'name': 'Centennial'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'flavour',
#                             'name': 'Amarillo'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'aroma',
#                             'name': 'Centennial'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'aroma',
#                             'name': 'Amarillo'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 37.5},
#                             'attribute': 'aroma',
#                             'name': 'Tomahawk'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 9.69},
#                             'name': 'Extra Pale'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.19},
#                             'name': 'Chocolate'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.44},
#                             'name': 'Carafa Special Malt Type 3'}],
#                   'yeast': 'Wyeast 3522 - Belgian Ardennes™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 21}},
#              'mash_temp': [{'duration': 105,
#                             'temp': {'unit': 'celsius', 'value': 69}}],
#              'twist': 'Aged in whisky barrels with raspberries, tayberries and '
#                       'blackberries'},
#   'name': 'AB:12',
#   'ph': 5.3,
#   'srm': 40,
#   'tagline': 'Imperial Black Belgian Ale.',
#   'target_fg': 1017,
#   'target_og': 1108,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 12.5,
#   'attenuation_level': 83,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'Authentic heather honey adds a beautiful floral top note '
#                   'that is unachievable any other way.',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': 'Whisky cask-aged imperial scotch ale. Beer perfect for when '
#                  'the rain is coming sideways. Liquorice, plum and raisin '
#                  'temper the warming alcohol, producing a beer capable of '
#                  'holding back the Scottish chill.',
#   'ebc': 84,
#   'first_brewed': '03/2010',
#   'food_pairing': ['Kedgeree',
#                    'Scotch broth with sourdough bread',
#                    'Clootie dumpling'],
#   'ibu': 30,
#   'id': 9,
#   'image_url': 'https://images.punkapi.com/v2/9.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'bitter',
#                             'name': 'Saaz'},
#                            {'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 31.3},
#                             'attribute': 'bitter',
#                             'name': 'First Gold'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 5.63},
#                             'name': 'Munich'},
#                            {'amount': {'unit': 'kilograms', 'value': 1.88},
#                             'name': 'Flaked Oats'},
#                            {'amount': {'unit': 'kilograms', 'value': 1.88},
#                             'name': 'Wheat'},
#                            {'amount': {'unit': 'kilograms', 'value': 1.25},
#                             'name': 'Caramalt'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.63},
#                             'name': 'Crystal'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.63},
#                             'name': 'Dark Crystal'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.31},
#                             'name': 'Chocolate'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.13},
#                             'name': 'Peated Malt'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.13},
#                             'name': 'Amber'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.13},
#                             'name': 'Brown'}],
#                   'yeast': 'Saflager S189'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 11}},
#              'mash_temp': [{'duration': 105,
#                             'temp': {'unit': 'celsius', 'value': 65}}],
#              'twist': 'Scottish Heather Honey: 62.5g at middle, Add honey '
#                       'during the boil. After fermentation, age in a Scottish '
#                       'whisky cask'},
#   'name': 'AB:07',
#   'ph': 5.6,
#   'srm': 42,
#   'tagline': 'Whisky Cask-Aged Scotch Ale.',
#   'target_fg': 1020,
#   'target_og': 1106,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 7.5,
#   'attenuation_level': 80.9,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'Getting good Bramling Cross is key. Most English hops are '
#                   'in leaf form (not pelletised), so getting fresh hops close '
#                   'to harvest (September) will give this beer the right amount '
#                   'of dark berry intensity.',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': 'Good old Bramling Cross is elegant, refined, assured, '
#                  '(boring) and understated. Understated that is unless you hop '
#                  'the living daylights out of a beer with it. This is Bramling '
#                  'Cross re-invented and re-imagined, and shows just what can '
#                  'be done with English hops if you use enough of them. Poor '
#                  'Bramling Cross normally gets lost in a woeful stream of '
#                  'conformist brown ales made by sleepy cask ale brewers. But '
#                  'not anymore. This beer shows that British hops do have some '
#                  'soul, and is a fruity riot of blackberries, pears, and '
#                  'plums. Reminds me of the bramble, apple and ginger jam my '
#                  'grandmother used to make.',
#   'ebc': 22,
#   'first_brewed': '01/2011',
#   'food_pairing': ['Warm blackberry pie',
#                    'Vinegar doused fish and chips',
#                    'Aromatic korma curry with lemon and garlic naan'],
#   'ibu': 75,
#   'id': 10,
#   'image_url': 'https://images.punkapi.com/v2/10.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 60},
#                             'attribute': 'bitter',
#                             'name': 'Bramling Cross'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 50},
#                             'attribute': 'flavour',
#                             'name': 'Bramling Cross'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 6.38},
#                             'name': 'Extra Pale'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.13},
#                             'name': 'Crystal 150'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.25},
#                             'name': 'Caramalt'}],
#                   'yeast': 'Wyeast 1056 - American Ale™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 19}},
#              'mash_temp': [{'duration': 75,
#                             'temp': {'unit': 'celsius', 'value': 65}}],
#              'twist': None},
#   'name': 'Bramling X',
#   'ph': 4.4,
#   'srm': 11,
#   'tagline': 'Single Hop IPA Series - 2011.',
#   'target_fg': 1013,
#   'target_og': 1068,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 7.3,
#   'attenuation_level': 74.7,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'Lots of malt in this one. Mash-in in stages, and spread the '
#                   'pale ale malt throughout the mash to provide stability. If '
#                   'the mash starts to sink, stop, wait a few minutes while '
#                   'mixing, then start again.',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': 'The brainchild of our small batch brewer, George Woods. A '
#                  'dangerously drinkable milk sugar- infused Scotch Ale.',
#   'ebc': 120,
#   'first_brewed': '04/2013',
#   'food_pairing': ['Roasted garlic and chilli infused camembert cheese',
#                    'Korean style chicken wings',
#                    'Chocolate milk shake'],
#   'ibu': 30,
#   'id': 11,
#   'image_url': 'https://images.punkapi.com/v2/keg.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'bitter',
#                             'name': 'First Gold'},
#                            {'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'bitter',
#                             'name': 'Fuggles'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 250},
#                             'attribute': 'Flavour',
#                             'name': 'Honey'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 375},
#                             'attribute': 'Flavour',
#                             'name': 'Lactose'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 10},
#                             'attribute': 'aroma',
#                             'name': 'First Gold'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 10},
#                             'attribute': 'aroma',
#                             'name': 'Fuggles'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 2.18},
#                             'name': 'Pale Ale'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.3},
#                             'name': 'Caramalt'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.3},
#                             'name': 'Dark Crystal'},
#                            {'amount': {'unit': 'kilograms', 'value': 1.8},
#                             'name': 'Smoked Weyermann'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.6},
#                             'name': 'Flaked Oats'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.6},
#                             'name': 'Brown'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.1},
#                             'name': 'Amber'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.05},
#                             'name': 'Chocolate'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.6},
#                             'name': 'Munich'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.2},
#                             'name': 'Crystal 150'}],
#                   'yeast': 'Wyeast 1056 - American Ale™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 19}},
#              'mash_temp': [{'duration': 75,
#                             'temp': {'unit': 'celsius', 'value': 67}}],
#              'twist': 'See honey and lactose additions'},
#   'name': 'Misspent Youth',
#   'ph': 4.4,
#   'srm': 60,
#   'tagline': 'Milk & Honey Scotch Ale.',
#   'target_fg': 1020,
#   'target_og': 1079,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 5.3,
#   'attenuation_level': 77,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'Be as accurate as possible when weighing out your malts to '
#                   'ensure you strike the right balance.',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': 'Running the knife-edge between an India Pale Ale and a '
#                  'Stout, this particular style is one we truly love. Black '
#                  'IPAs are a great showcase for the skill of our brew team, '
#                  'balancing so many complex and twisting flavours in the same '
#                  'moment. The citrus, mango and pine from the hops – three of '
#                  'our all-time favourites – play off against the roasty '
#                  'dryness from the malt bill at each and every turn.',
#   'ebc': 200,
#   'first_brewed': '12/2015',
#   'food_pairing': ['King prawn kebabs',
#                    'Halibut with a mango and tomato salad',
#                    'Mint chocloate ice cream'],
#   'ibu': 60,
#   'id': 12,
#   'image_url': 'https://images.punkapi.com/v2/12.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'bitter',
#                             'name': 'Simcoe'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 19},
#                             'attribute': 'flavour',
#                             'name': 'Simcoe'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Simcoe'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Amarillo'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Citra'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 62.5},
#                             'attribute': 'aroma',
#                             'name': 'Simcoe'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 62.5},
#                             'attribute': 'aroma',
#                             'name': 'Amarillo'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 62.5},
#                             'attribute': 'aroma',
#                             'name': 'Citra'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 3.13},
#                             'name': 'Pale Ale'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.25},
#                             'name': 'Caramalt'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.18},
#                             'name': 'Crystal 150'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.25},
#                             'name': 'Carafa Special Malt Type 1'}],
#                   'yeast': 'Wyeast 1056 - American Ale™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 19}},
#              'mash_temp': [{'duration': None,
#                             'temp': {'unit': 'celsius', 'value': 65}}],
#              'twist': None},
#   'name': 'Arcade Nation',
#   'ph': 4.2,
#   'srm': 100,
#   'tagline': 'Seasonal Black IPA.',
#   'target_fg': 1012,
#   'target_og': 1052,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 14.5,
#   'attenuation_level': 85,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'Brew twice as much Belgian Tripel as you were planning on '
#                   "ageing - it's awesome on its own too!",
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': 'This recipe is for the Belgian Tripel base. A blend of two '
#                  'huge oak aged beers – half a hopped up Belgian Tripel, and '
#                  'half a Triple India Pale Ale. Both aged in single grain '
#                  'whisky barrels for two years and blended, each beer brings '
#                  'its own character to the mix. The Belgian Tripel comes '
#                  'loaded with complex spicy, fruity esters, and punchy citrus '
#                  'hop character.',
#   'ebc': 40,
#   'first_brewed': '01/2012',
#   'food_pairing': ['Coriander & chilli crab cakes',
#                    'Goats cheese salad with walnuts, radish and blood orange',
#                    'Pistachio cake'],
#   'ibu': 50,
#   'id': 15,
#   'image_url': 'https://images.punkapi.com/v2/15.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'bitter',
#                             'name': 'Columbus Extract'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 37.5},
#                             'attribute': 'flavour',
#                             'name': 'Centennial'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 37.5},
#                             'attribute': 'flavour',
#                             'name': 'Cascade'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 37.5},
#                             'attribute': 'flavour',
#                             'name': 'Simcoe'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 11.1},
#                             'name': 'Pale Ale - Tipple'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.94},
#                             'name': 'Caramalt'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.44},
#                             'name': 'Crystal'}],
#                   'yeast': 'Wyeast 3522 - Belgian Ardennes™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 21}},
#              'mash_temp': [{'duration': 40,
#                             'temp': {'unit': 'celsius', 'value': 65}}],
#              'twist': 'Barrel aged and blended with Anarchist Alchemist'},
#   'name': 'Mixtape 8',
#   'ph': 4.4,
#   'srm': 20,
#   'tagline': 'An Epic Fusion Of Old Belgian, American New Wave, And Scotch '
#              'Whisky.',
#   'target_fg': 1014,
#   'target_og': 1093,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 6.1,
#   'attenuation_level': 70.1,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'Mash in at a higher temperature to leave more unfermentable '
#                   'sugars in the wort. This gives the beer a sweeter porter '
#                   'profile.',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': 'An avalanche of cross-continental hop varieties give this '
#                  'porter a complex spicy, resinous and citrusy aroma, with a '
#                  'huge malt bill providing a complex roasty counterpoint. '
#                  'Digging deeper into the flavour draws out cinder toffee, '
#                  'bitter chocolate and hints of woodsmoke.',
#   'ebc': 219,
#   'first_brewed': '01/2012',
#   'food_pairing': ['Blue cheese beef burger',
#                    'Glazed short ribs',
#                    'Chocolate cake'],
#   'ibu': 45,
#   'id': 16,
#   'image_url': 'https://images.punkapi.com/v2/16.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 31.25},
#                             'attribute': 'bitter',
#                             'name': 'Columbus'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'bitter',
#                             'name': 'Columbus'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'flavour',
#                             'name': 'Willamette'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'flavour',
#                             'name': 'Galena'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 75},
#                             'attribute': 'aroma',
#                             'name': 'Columbus'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 75},
#                             'attribute': 'aroma',
#                             'name': 'Galena'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 100},
#                             'attribute': 'aroma',
#                             'name': 'Simcoe'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 5},
#                             'name': 'Extra Pale - Spring Blend'},
#                            {'amount': {'unit': 'kilograms', 'value': 1.25},
#                             'name': 'Caramalt'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.63},
#                             'name': 'Crystal 150'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.63},
#                             'name': 'Chocolate'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.63},
#                             'name': 'Roasted Barley'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.31},
#                             'name': 'Wheat'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.31},
#                             'name': 'Flaked Oats'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.06},
#                             'name': 'Smoked Malt'}],
#                   'yeast': 'Wyeast 1056 - American Ale™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 18}},
#              'mash_temp': [{'duration': 35,
#                             'temp': {'unit': 'celsius', 'value': 68}}],
#              'twist': None},
#   'name': 'Libertine Porter',
#   'ph': 4.4,
#   'srm': 109.5,
#   'tagline': 'Dry-Hopped Aggressive Porter.',
#   'target_fg': 1020,
#   'target_og': 1067,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 11.2,
#   'attenuation_level': 87,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'Boil down to desired OG (about 17 litres).',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': 'Our sixth Abstrakt, this imperial black IPA combined dark '
#                  'malts with a monumental triple dry-hop, using an all-star '
#                  'team of some of our favourite American hops. Roasty and '
#                  'resinous.',
#   'ebc': 70,
#   'first_brewed': '04/2011',
#   'food_pairing': ['Coffee dusted venison loin',
#                    'Memphis-style beef short ribs',
#                    'Chocolate orange brownies'],
#   'ibu': 150,
#   'id': 17,
#   'image_url': 'https://images.punkapi.com/v2/17.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 20},
#                             'attribute': 'bitter',
#                             'name': 'Hop Extract'},
#                            {'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'bitter',
#                             'name': 'Amarillo'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'flavour',
#                             'name': 'Chinook'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'flavour',
#                             'name': 'Cascade'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'flavour',
#                             'name': 'Centennial'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'flavour',
#                             'name': 'Columbus'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'aroma',
#                             'name': 'Chinook'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'aroma',
#                             'name': 'Cascade'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'aroma',
#                             'name': 'Centennial'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'aroma',
#                             'name': 'Columbus'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'aroma',
#                             'name': 'Amarillo'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 6.13},
#                             'name': 'Pale Ale'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.25},
#                             'name': 'Crystal 150'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.38},
#                             'name': 'Caramalt'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.13},
#                             'name': 'Carafa Special Malt Type 1'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.13},
#                             'name': 'Carafa Special Malt Type 3'}],
#                   'yeast': 'Wyeast 1272 - American Ale II™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 17}},
#              'mash_temp': [{'duration': 90,
#                             'temp': {'unit': 'celsius', 'value': 65}}],
#              'twist': 'White cane sugar: 150g at middle'},
#   'name': 'AB:06',
#   'ph': None,
#   'srm': 35,
#   'tagline': 'Imperial Black IPA.',
#   'target_fg': 1013,
#   'target_og': 1098,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 6,
#   'attenuation_level': 79.3,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'Create balance through experimentation with the hop amounts '
#                   'and malt backbone.',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': 'The levels of hops vary throughout the range. We love hops, '
#                  'so all four beers are big, bitter badasses, but by tweaking '
#                  'the amount of each hop used later in the boil and during '
#                  'dry- hopping, we can balance the malty backbone with some '
#                  'unexpected flavours. Simcoe is used in the whirlpool for all '
#                  'four beers, and yet still lends different characters to each',
#   'ebc': 25,
#   'first_brewed': '08/2014',
#   'food_pairing': ['Spicy chicken skewers',
#                    'Fish tacos with hot sauce',
#                    'Lemon pound cake with a ice sugar glaze'],
#   'ibu': 70,
#   'id': 18,
#   'image_url': 'https://images.punkapi.com/v2/18.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 2.5},
#                             'attribute': 'bitter',
#                             'name': 'Cascade'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Centennial'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 17.5},
#                             'attribute': 'flavour',
#                             'name': 'Simcoe'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 17.5},
#                             'attribute': 'flavour',
#                             'name': 'Simcoe'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 17.5},
#                             'attribute': 'flavour',
#                             'name': 'Citra'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 75},
#                             'attribute': 'aroma',
#                             'name': 'Simcoe'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 75},
#                             'attribute': 'aroma',
#                             'name': 'Cascade'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 75},
#                             'attribute': 'aroma',
#                             'name': 'Centennial'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'aroma',
#                             'name': 'Citra'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 5.06},
#                             'name': 'Extra Pale'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.25},
#                             'name': 'Caramalt'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.06},
#                             'name': 'Dark Crystal'}],
#                   'yeast': 'Wyeast 1056 - American Ale™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 19}},
#              'mash_temp': [{'duration': 75,
#                             'temp': {'unit': 'celsius', 'value': 65}}],
#              'twist': None},
#   'name': 'Russian Doll – India Pale Ale',
#   'ph': 5.2,
#   'srm': 12.5,
#   'tagline': 'Nesting Hop Bomb.',
#   'target_fg': 1012,
#   'target_og': 1058,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 8.2,
#   'attenuation_level': 83,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'Using crushed cranberries will dry out the beer further, '
#                   'drawing out their natural astringent character.',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': "We sent this beer to Norway where it was known as 'Hello, my "
#                  'name is Censored’. You can make up your own mind as to why. '
#                  'This brew was a red berry explosion, with a reisnous bitter '
#                  'edge layered with dry berry tartness.',
#   'ebc': None,
#   'first_brewed': '06/2013',
#   'food_pairing': ['Fårikål (mutton stew) with a spicy twist',
#                    'Fenalår (salted cured lamb)',
#                    'Krumkake with lingonberry jam'],
#   'ibu': 70,
#   'id': 19,
#   'image_url': 'https://images.punkapi.com/v2/19.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 7},
#                             'attribute': 'bitter',
#                             'name': 'Tomahawk'},
#                            {'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 5.5},
#                             'attribute': 'bitter',
#                             'name': 'Motueka'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 2.5},
#                             'attribute': 'flavour',
#                             'name': 'Galena'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 2.5},
#                             'attribute': 'flavour',
#                             'name': 'Mt.Hood'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 15},
#                             'attribute': 'aroma',
#                             'name': 'Challenger'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 15},
#                             'attribute': 'aroma',
#                             'name': 'Galena'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 20},
#                             'attribute': 'aroma',
#                             'name': 'Nelson Sauvin'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 6.12},
#                             'name': 'Extra Pale'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.8},
#                             'name': 'Caramalt'}],
#                   'yeast': 'Wyeast 1056 - American Ale™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 19}},
#              'mash_temp': [{'duration': 90,
#                             'temp': {'unit': 'celsius', 'value': 66}}],
#              'twist': 'Infusion of lingonberries alongside the dry hops, '
#                       'Cranberry Juice: 5.5g at 30mins, Lingonberries: 10g '
#                       'Twist'},
#   'name': 'Hello My Name Is Mette-Marit',
#   'ph': 4.4,
#   'srm': None,
#   'tagline': 'Lingonberry Double IPA.',
#   'target_fg': 1013,
#   'target_og': 1076,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 10.27,
#   'attenuation_level': 85,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'If you are struggling to get that authentic head retention '
#                   'increase your mash temperature to about 70°C.',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': 'Imperial Wheat beer / Weizenbock brewed by a homesick German '
#                  'in leather trousers. Think banana bread, bubble gum and '
#                  'David Hasselhoff.',
#   'ebc': 24,
#   'first_brewed': '03/2011',
#   'food_pairing': ['Grilled portabello mushroom burger',
#                    'Chicken sausages with creamy mash',
#                    'Caramel and banana meringue pie'],
#   'ibu': 26,
#   'id': 20,
#   'image_url': 'https://images.punkapi.com/v2/keg.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'bitter',
#                             'name': 'Columbus'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Hersbrucker'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 5.63},
#                             'name': 'Extra Pale'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.69},
#                             'name': 'Wheat'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.63},
#                             'name': 'Crystal'}],
#                   'yeast': 'Wyeast 3333 - German Wheat™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 21}},
#              'mash_temp': [{'duration': 60,
#                             'temp': {'unit': 'celsius', 'value': 64}}],
#              'twist': None},
#   'name': 'Rabiator',
#   'ph': 4.4,
#   'srm': 12,
#   'tagline': 'Imperial Wheat Beer',
#   'target_fg': 1014,
#   'target_og': 1092,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 12.5,
#   'attenuation_level': 68,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'Rack off to a secondary fermenter before pitching in some '
#                   'champagne.',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': "Two of Europe's most experimental, boundary-pushing brewers, "
#                  'BrewDog and Mikkeller, combined forces to produce a '
#                  'rebellious beer that combined their respective talents and '
#                  'brewing skills. The 12.5% Barley Wine fermented well, and '
#                  'the champagne yeast drew it ever closer to 12.5%. The beer '
#                  'was brewed with a single hop variety and was going to be '
#                  'partially aged in oak casks.',
#   'ebc': 36,
#   'first_brewed': '12/2008',
#   'food_pairing': ['Stilton on gingerbread biscuits',
#                    'Pot roasted artichokes',
#                    'Lamb chops with caramelised figs'],
#   'ibu': 100,
#   'id': 22,
#   'image_url': 'https://images.punkapi.com/v2/22.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 100},
#                             'attribute': 'bitter',
#                             'name': 'Nelson Sauvin'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 100},
# ...
#                             'attribute': 'bitter',
#                             'name': 'Cascade'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 6},
#                             'attribute': 'flavour',
#                             'name': 'Cascade'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Saaz'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Hersbrucker'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 3},
#                             'name': 'Extra Pale'},
#                            {'amount': {'unit': 'kilograms', 'value': 2},
#                             'name': 'Wheat'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.08},
#                             'name': 'Dark Crystal'}],
#                   'yeast': 'Wyeast 3638 - Bavarian Wheat™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 21}},
#              'mash_temp': [{'duration': None,
#                             'temp': {'unit': 'celsius', 'value': 65}}],
#              'twist': None},
#   'name': 'India Pale Weizen (w/ Weihenstephan)',
#   'ph': 4,
#   'srm': 17.5,
#   'tagline': 'BrewDog Versus Weihenstephan.',
#   'target_fg': 1010,
#   'target_og': 1056,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 8.2,
#   'attenuation_level': 83.3,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'For easy addition, freeze the berries and then allow to '
#                   'defrost. The process will turn the berries to mush.',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': 'A Scottish take on Hello My Name is Ingrid with added '
#                  'brambles. Caramel malt provides sweetness to balance the '
#                  'tart berry character, which loses sweetness during '
#                  'fermentation.',
#   'ebc': 90,
#   'first_brewed': '08/2012',
#   'food_pairing': ['Honey glazed ham with pineapple',
#                    'Spicy wings with blue cheese sauce',
#                    'Blackberry pie with vanilla ice cream'],
#   'ibu': 42,
#   'id': 105,
#   'image_url': 'https://images.punkapi.com/v2/105.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'bitter',
#                             'name': 'Columbus'},
#                            {'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'bitter',
#                             'name': 'Centennial'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Columbus'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Centennial'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 25},
#                             'attribute': 'flavour',
#                             'name': 'Nelson Sauvin'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 37.5},
#                             'attribute': 'flavour',
#                             'name': 'Bramling Cross/ First Gold'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 71.43},
#                             'attribute': 'aroma',
#                             'name': 'Columbus'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 71.43},
#                             'attribute': 'aroma',
#                             'name': 'Centennial'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 71.43},
#                             'attribute': 'aroma',
#                             'name': 'Nelson Sauvin'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 6.86},
#                             'name': 'Maris Otter Extra Pale'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.93},
#                             'name': 'Caramalt'}],
#                   'yeast': 'Wyeast 1272 - American Ale II™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 21}},
#              'mash_temp': [{'duration': 90,
#                             'temp': {'unit': 'celsius', 'value': 64}}],
#              'twist': '500g bramble addition in the FV'},
#   'name': 'Hello My Name Is Beastie',
#   'ph': 4.4,
#   'srm': 45,
#   'tagline': 'Double IPA Brewed with Brambles.',
#   'target_fg': 1013,
#   'target_og': 1078,
#   'volume': {'unit': 'litres', 'value': 20}},
#  {'abv': 5.6,
#   'attenuation_level': 78,
#   'boil_volume': {'unit': 'litres', 'value': 25},
#   'brewers_tips': 'To get the best possible profile from the dry hops we '
#                   'recommend dry hopping post fermentation for 5 days. Dry '
#                   'hops should be added at cellar temperature. We find 14°C '
#                   'results in the most aromatic dry hop profile.',
#   'contributed_by': 'Sam Mason <samjbmason>',
#   'description': 'Punk IPA. Amplified. In 2010 we finally got our paws on the '
#                  'equipment we needed to dry hop our beers. We focused all our '
#                  'energy on dry hopping, amping up the aroma and flavour of '
#                  'our flagship beer to create a relentless explosion of '
#                  'tropical fruits, and adding a hint of Caramalt to balance '
#                  'out the insane amount of hops.',
#   'ebc': 15,
#   'first_brewed': '10/2010',
#   'food_pairing': ['Spicy carne asada with a pico de gallo sauce',
#                    'Shredded chicken tacos with a mango chilli lime salsa',
#                    'Cheesecake with a passion fruit swirl sauce'],
#   'ibu': 40,
#   'id': 106,
#   'image_url': 'https://images.punkapi.com/v2/106.png',
#   'ingredients': {'hops': [{'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 20},
#                             'attribute': 'bitter',
#                             'name': 'Chinook'},
#                            {'add': 'start',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'bitter',
#                             'name': 'Ahtanum'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 20},
#                             'attribute': 'flavour',
#                             'name': 'Chinook'},
#                            {'add': 'middle',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Ahtanum'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 27.5},
#                             'attribute': 'flavour',
#                             'name': 'Chinook'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Ahtanum'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Simcoe'},
#                            {'add': 'end',
#                             'amount': {'unit': 'grams', 'value': 12.5},
#                             'attribute': 'flavour',
#                             'name': 'Nelson Sauvin'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 47.5},
#                             'attribute': 'aroma',
#                             'name': 'Chinook'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 37.5},
#                             'attribute': 'aroma',
#                             'name': 'Ahtanum'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 37.5},
#                             'attribute': 'aroma',
#                             'name': 'Simcoe'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 20},
#                             'attribute': 'aroma',
#                             'name': 'Nelson Sauvin'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 37.5},
#                             'attribute': 'aroma',
#                             'name': 'Cascade'},
#                            {'add': 'dry hop',
#                             'amount': {'unit': 'grams', 'value': 10},
#                             'attribute': 'aroma',
#                             'name': 'Amarillo'}],
#                   'malt': [{'amount': {'unit': 'kilograms', 'value': 4.38},
#                             'name': 'Extra Pale'},
#                            {'amount': {'unit': 'kilograms', 'value': 0.25},
#                             'name': 'Caramalt'}],
#                   'yeast': 'Wyeast 1056 - American Ale™'},
#   'method': {'fermentation': {'temp': {'unit': 'celsius', 'value': 19}},
#              'mash_temp': [{'duration': 75,
#                             'temp': {'unit': 'celsius', 'value': 66}}],
#              'twist': None},
#   'name': 'Punk IPA 2010 - Current',
#   'ph': 4.4,
#   'srm': 7.6,
#   'tagline': 'Post Modern Classic. Spiky. Tropical. Hoppy.',
#   'target_fg': 1011,
#   'target_og': 1055,
#   'volume': {'unit': 'litres', 'value': 20}}]
#
# JSON response without pretty printer:
# [{'id': 4, 'name': 'Pilsen Lager', 'tagline': 'Unleash the Yeast Series.', 'first_brewed': '09/2013', 'description': 'Our Unleash the Yeast series was an epic experiment into the differences in aroma and flavour provided by switching up your yeast. We brewed up a wort with a light caramel note and some toasty biscuit flavour, and hopped it with Amarillo and Centennial for a citrusy bitterness. Everything else is down to the yeast. Pilsner yeast ferments with no fruity esters or spicy phenols, although it can add a hint of butterscotch.', 'image_url': 'https://images.punkapi.com/v2/4.png', 'abv': 6.3, 'ibu': 55, 'target_fg': 1012, 'target_og': 1060, 'ebc': 30, 'srm': 15, 'ph': 4.4, 'attenuation_level': 80, 'volume': {'value': 20, 'unit': 'litres'}, 'boil_volume': {'value': 25, 'unit': 'litres'}, 'method': {'mash_temp': [{'temp': {'value': 65, 'unit': 'celsius'}, 'duration': None}], 'fermentation': {'temp': {'value': 9, 'unit': 'celsius'}}, 'twist': None}, 'ingredients': {'malt': [{'name': 'Extra Pale', 'amount': {'value': 4.58, 'unit': 'kilograms'}}, {'name': 'Caramalt', 'amount': {'value': 0.25, 'unit': 'kilograms'}}, {'name': 'Dark Crystal', 'amount': {'value': 0.06, 'unit': 'kilograms'}}, {'name': 'Munich', 'amount': {'value': 0.25, 'unit': 'kilograms'}}], 'hops': [{'name': 'Centennial', 'amount': {'value': 5, 'unit': 'grams'}, 'add': 'start', 'attribute': 'bitter'}, {'name': 'Amarillo', 'amount': {'value': 5, 'unit': 'grams'}, 'add': 'start', 'attribute': 'bitter'}, {'name': 'Centennial', 'amount': {'value': 10, 'unit': 'grams'}, 'add': 'middle', 'attribute': 'flavour'}, {'name': 'Amarillo', 'amount': {'value': 10, 'unit': 'grams'}, 'add': 'middle', 'attribute': 'flavour'}, {'name': 'Centennial', 'amount': {'value': 17.5, 'unit': 'grams'}, 'add': 'end', 'attribute': 'flavour'}, {'name': 'Amarillo', 'amount': {'value': 17.5, 'unit': 'grams'}, 'add': 'end', 'attribute': 'flavour'}], 'yeast': 'Wyeast 2007 - Pilsen Lager™'}, 'food_pairing': ['Spicy crab cakes', 'Spicy cucumber and carrot Thai salad', 'Sweet filled dumplings'], 'brewers_tips': 'Play around with the fermentation temperature to get the best flavour profile from the individual yeasts.', 'contributed_by': 'Ali Skinner <AliSkinner>'}, {'id': 5, 'name': 'Avery Brown Dredge', 'tagline': "Bloggers' Imperial Pilsner.", 'first_brewed': '02/2011', 'description': 'An Imperial Pilsner in collaboration with beer writers. Tradition. Homage. Revolution. We wanted to showcase the awesome backbone of the Czech brewing tradition, the noble Saaz hop, and also tip our hats to the modern beers that rock our world, and the people who make them.', 'image_url': 'https://images.punkapi.com/v2/5.png', 'abv': 7.2, 'ibu': 59, 'target_fg': 1027, 'target_og': 1069, 'ebc': 10, 'srm': 5, 'ph': 4.4, 'attenuation_level': 67, 'volume': {'value': 20, 'unit': 'litres'}, 'boil_volume': {'value': 25, 'unit': 'litres'}, 'method': {'mash_temp': [{'temp': {'value': 66, 'unit': 'celsius'}, 'duration': 70}], 'fermentation': {'temp': {'value': 10, 'unit': 'celsius'}}, 'twist': None}, 'ingredients': {'malt': [{'name': 'Lager Malt', 'amount': {'value': 6.63, 'unit': 'kilograms'}}, {'name': 'Wheat', 'amount': {'value': 0.38, 'unit': 'kilograms'}}], 'hops': [{'name': 'Saaz', 'amount': {'value': 60, 'unit': 'grams'}, 'add': 'start', 'attribute': 'bitter'}, {'name': 'Saaz', 'amount': {'value': 60, 'unit': 'grams'}, 'add': 'middle', 'attribute': 'flavour'}, {'name': 'Saaz', 'amount': {'value': 60, 'unit': 'grams'}, 'add': 'end', 'attribute': 'flavour'}], 'yeast': 'Wyeast 2007 - Pilsen Lager™'}, 'food_pairing': ['Vietnamese squid salad', 'Chargrilled corn on the cob with paprika butter', 'Strawberry and rhubarb pie'], 'brewers_tips': 'Make sure you have a big enough yeast starter to ferment through the OG and lager successfully.', 'contributed_by': 'Sam Mason <samjbmason>'}, {'id': 6, 'name': 'Electric India', 'tagline': 'Vibrant Hoppy Saison.', 'first_brewed': '05/2013', 'description': 'Re-brewed as a spring seaso ...
#
# 3) Names of the beers in lower case:
# pilsen lager
# avery brown dredge
# electric india
# ab:12
# ab:07
# bramling x
# misspent youth
# arcade nation
# mixtape 8
# libertine porter
# ab:06
# russian doll – india pale ale
# hello my name is mette-marit
# rabiator
# devine rebel (w/ mikkeller)
# storm
# the end of history
# dog b
# hbc 369
# 10 heads high
# dana - ipa is dead
# ab:05
# sorachi ace
# bourbon baby
# shipwrecker circus (w/ oskar blues)
# zephyr
# belgian trappist
# kohatu - ipa is dead
# hello my name is vladimir
# ab:17
# hardcore ipa
# dog wired (w/8 wired)
# anarchist alchemist
# ab:15
# goldings - ipa is dead
# ab:14
# lost dog (w/lost abbey)
# tm10
# paradox islay
# albino squid assasin
# amarillo - ipa is dead
# black eyed king imp
# prototype 27
# coffee imperial stout
# mandarina bavaria - ipa is dead
# dogma
# ab:08
# sunk punk
# sub hop
# tokyo rising sun - lowland
# hunter foundation pale ale
# ab:16
# sunmaid stout
# whisky sour - b-sides
# black eyed king imp - vietnamese coffee edition
# never mind the anabolics
# #mashtag 2013
# ab:18
# hops kill nazis
# ab:04
# hopped-up brown ale - prototype challenge
# comet
# original dogma (née speedball)
# bavarian weizen
# citra
# #mashtag 2015
# ab:09
# mango gose - b-sides
# everday anarchy
# lumberjack stout
# bowman's beard - b-sides
# pumpkin king
# hello my name is päivi
# elvis juice v2.0 - prototype challenge
# riptide
# peach therapy
# clown king
# india pale weizen (w/ weihenstephan)
# hello my name is beastie
# punk ipa 2010 - current
#
# 4) Suggested food pairing for Rabiator:
# ['Grilled portabello mushroom burger',
#  'Chicken sausages with creamy mash',
#  'Caramel and banana meringue pie']
#
# 5) Malt ingredients for Hello My Name Is Beastie:
# [{'amount': {'unit': 'kilograms', 'value': 6.86},
#   'name': 'Maris Otter Extra Pale'},
#  {'amount': {'unit': 'kilograms', 'value': 0.93}, 'name': 'Caramalt'}]

# %% [markdown]
# > **Ex. 5.4.3:** Save the beers as a JSON file on your machine.
#
# > _Hint:_ If still in doubt about how to do this, you might want to take a look at the [json](https://docs.python.org/3/library/json.html) module.

# %%
# YOUR CODE HERE

# Save the beers data as a JSON file
with open('beers_data.json', 'w') as json_file:
    json.dump(beers_data, json_file)

# %% [markdown]
# ## The API for Statistics Denmark
#
# Statistics Denmark (DST) provide an API access to their aggregate data. For developers, they supply a [console](https://api.statbank.dk/console) for testing. In this exercise, we will code up a simple script which can collect data from the DST API.
#
# > **Ex 5.4.4:** Use the API console to construct a GET request which retrieves the table FOLK1A split by quarter. The return should be in JSON format. We want all available dates.
# >
# >Then write a function `construct_link()` which takes as inputs: a table ID (e.g. `'FOLK1A'`) and a list of strings like `['var1=*', 'var2=somevalue']`. The function should return the proper URL for getting a dataset with the specified variables (e.g. in this case all levels of var1, but only where var2=somevalue).
#
# > _Hint:_ The time variable is called 'tid'. To select all available values, set the value-id to '*'. Spend a little time with the console to get a sense of how the URLs are constructed.

# %%
# YOUR CODE HERE

# YOUR CODE HERE
def construct_link(table_id, variable_list):
    base_url = "https://api.statbank.dk/v1/data"
    variables = "&".join(variable_list)
    link = f"{base_url}/{table_id}/JSONSTAT?{variables}"
    return link

# Example usage
table_id = "FOLK1A"
variables = []
url = construct_link(table_id, variables)
print(url)
# Out:
# https://api.statbank.dk/v1/data/FOLK1A/JSONSTAT?

# %%
## dstapi test

from dstapi import DstApi # install with `pip install git+https://github.com/alemartinello/dstapi`

ind = DstApi('FOLK1A') 

tabsum = ind.tablesummary(language='da')
display(tabsum)

"""""
# The available values for a each variable: 
for variable in tabsum['variable name']:
    print(variable+':')
    display(ind.variable_levels(variable, language='en'))
"""""
params = ind._define_base_params(language='en')
params
# Out:
# Table FOLK1A: Folketal den 1. i kvartalet efter område, køn, alder, civilstand og tid
# Last update: 2023-05-10T08:00:00
#   variable name  # values First value First value label Last value  \
# 0        OMRÅDE       105         000       Hele landet        851
# 1           KØN         3         TOT             I alt          2
# 2         ALDER       127        IALT       Alder i alt        125
# 3    CIVILSTAND         5         TOT             I alt          F
# 4           Tid        62      2008K1            2008K1     2023K2
#
#   Last value label  Time variable
# 0          Aalborg          False
# 1          Kvinder          False
# 2           125 år          False
# 3         Fraskilt          False
# 4           2023K2           True
# {'table': 'folk1a',
#  'format': 'BULK',
#  'lang': 'en',
#  'variables': [{'code': 'OMRÅDE', 'values': ['*']},
#   {'code': 'KØN', 'values': ['*']},
#   {'code': 'ALDER', 'values': ['*']},
#   {'code': 'CIVILSTAND', 'values': ['*']},
#   {'code': 'Tid', 'values': ['*']}]}

# %%
display(ind.tablesummary(language='en'))
display(ind.variable_levels('OMRÅDE', language='en'))
# Out:
# Table FOLK1A: Folketal den 1. i kvartalet efter område, køn, alder, civilstand og tid
# Last update: 2023-05-10T08:00:00
#   variable name  # values First value First value label Last value  \
# 0        OMRÅDE       105         000       Hele landet        851
# 1           KØN         3         TOT             I alt          2
# 2         ALDER       127        IALT       Alder i alt        125
# 3    CIVILSTAND         5         TOT             I alt          F
# 4           Tid        62      2008K1            2008K1     2023K2
#
#   Last value label  Time variable
# 0          Aalborg          False
# 1          Kvinder          False
# 2           125 år          False
# 3         Fraskilt          False
# 4           2023K2           True
#       id                text
# 0    000         Hele landet
# 1    084  Region Hovedstaden
# 2    101           København
# 3    147       Frederiksberg
# 4    155              Dragør
# ..   ...                 ...
# 100  773               Morsø
# 101  840              Rebild
# 102  787             Thisted
# 103  820     Vesthimmerlands
# 104  851             Aalborg
#
# [105 rows x 2 columns]

# %% [markdown]
# When executing the request in the console, you should get a json file as output. Next, lets write some code to load these json files directly into python.
#
#
# > **Ex. 5.4.5:** Use the `requests` module and `construct_link()` to request home value data from the "EJDFOE1" table. Get all available years (variable "Tid"), but only for Frederiksberg (BOPKOM=147), apartments (EJENTYP=B), market values (VAERDI=100) and average values in DKK units (ENHED=120). Unpack the json payload and store the result. Wrap the whole thing in a function which takes an url as input and returns the corresponding output.
#
# > _Hint:_ The `requests.response` object has a `.json()` method.

# %%
# YOUR CODE HERE

def get_data_from_url(api_url):
    response = requests.get(api_url)
    if response.status_code == 200:
        data = response.json()
    return data

# Example usage
table_id = "EJDFOE1"
variables = ['Tid=*', 'BOPKOM=147', 'EJENTYP=B', 'VAERDI=100', 'ENHED=120']
api_link = construct_link(table_id, variables)
result = get_data_from_url(api_link)
print(result)
# Out:
# {'dataset': {'dimension': {'VAERDI': {'label': 'værdisætning', 'category': {'index': {'100': 0}, 'label': {'100': 'Markedsværdi'}}}, 'BOPKOM': {'label': 'bopælskommune', 'category': {'index': {'147': 0}, 'label': {'147': 'Frederiksberg'}}}, 'ENHED': {'label': 'enhed', 'category': {'index': {'120': 0}, 'label': {'120': 'Gennemsnit (Kr.)'}}}, 'EJENTYP': {'label': 'ejendomstype', 'category': {'index': {'B': 0}, 'label': {'B': 'B. Ejerlejligheder'}}}, 'ContentsCode': {'label': 'Indhold', 'category': {'index': {'EJDFOE1': 0}, 'label': {'EJDFOE1': 'Formue i fast ejendom'}, 'unit': {'EJDFOE1': {'base': '-', 'decimals': 0}}}}, 'Tid': {'label': 'tid', 'category': {'index': {'2004': 0, '2005': 1, '2006': 2, '2007': 3, '2008': 4, '2009': 5, '2010': 6, '2011': 7, '2012': 8, '2013': 9, '2014': 10, '2015': 11, '2016': 12, '2017': 13, '2018': 14, '2019': 15, '2020': 16, '2021': 17, '2022': 18}, 'label': {'2004': '2004', '2005': '2005', '2006': '2006', '2007': '2007', '2008': '2008', '2009': '2009', '2010': '2010', '2011': '2011', '2012': '2012', '2013': '2013', '2014': '2014', '2015': '2015', '2016': '2016', '2017': '2017', '2018': '2018', '2019': '2019', '2020': '2020', '2021': '2021', '2022': '2022'}}}, 'id': ['VAERDI', 'BOPKOM', 'ENHED', 'EJENTYP', 'ContentsCode', 'Tid'], 'size': [1, 1, 1, 1, 1, 19], 'role': {'geo': ['BOPKOM'], 'metric': ['ContentsCode'], 'time': ['Tid']}}, 'label': 'Formue i fast ejendom efter værdisætning, bopælskommune, enhed, ejendomstype, Indhold og tid', 'source': 'Danmarks Statistik', 'updated': '2023-06-29T06:00:00Z', 'value': [1831863, 2432527, 2967807, 2689005, 2411340, 2169275, 2404517, 2476094, 2603080, 2780182, 3043468, 3360457, 3514799, 3671493, 3744034, 3762944, 3792786, 3763303, 3640595], 'extension': {'px': {'infofile': 'https://www.dst.dk/statistikdokumentation/3639352a-44e6-42b3-8fdf-674da77f486d', 'tableid': 'EJDFOE1', 'decimals': 0}}}}

# %% [markdown]
# > **Ex. 5.4.6:** Extract the values for Frederiksberg in each year. Store the results as a list.

# %%
# YOUR CODE HERE

# Extracting necessary information
frederiksberg_index = result['dataset']['dimension']['BOPKOM']['category']['index']['147']
years = result['dataset']['dimension']['Tid']['category']['label']

frederiksberg_values = []

for i, year in enumerate(years):
    value_index = i
    val1 = result['dataset']['value'][value_index]
    frederiksberg_values.append((year, val1))

print(frederiksberg_values)
# Out:
# [('2004', 1831863), ('2005', 2432527), ('2006', 2967807), ('2007', 2689005), ('2008', 2411340), ('2009', 2169275), ('2010', 2404517), ('2011', 2476094), ('2012', 2603080), ('2013', 2780182), ('2014', 3043468), ('2015', 3360457), ('2016', 3514799), ('2017', 3671493), ('2018', 3744034), ('2019', 3762944), ('2020', 3792786), ('2021', 3763303), ('2022', 3640595)]

# %% [markdown]
# > **Ex. 5.4.7:** Repeat 5.4.5 and 5.4.6 but this time only for Copenhagen (BOPKOM=101). Store the numbers in a new list and use the `plot_values` (supplied below) function to plot the (log of) the data. Interpret the plot.

# %%
# YOUR CODE HERE

def get_data_from_url(api_url):
    response = requests.get(api_url)
    if response.status_code == 200:
        data = response.json()
        return data

# Example usage
table_id = "EJDFOE1"
variables = ['Tid=*', 'BOPKOM=101', 'EJENTYP=B', 'VAERDI=100', 'ENHED=120']
api_link = construct_link(table_id, variables)
result = get_data_from_url(api_link)
    
# Extracting necessary information
København_index = result['dataset']['dimension']['BOPKOM']['category']['index']['101']
years = result['dataset']['dimension']['Tid']['category']['label']

København_values = []

for i, year in enumerate(years):
    value_index = i
    val2 = result['dataset']['value'][value_index]
    København_values.append((year, val2))
print(København_values)

import pandas as pd

# Create dataframes from the lists
frederiksberg_df = pd.DataFrame(frederiksberg_values, columns=['Year', 'Val2'])
københavn_df = pd.DataFrame(København_values, columns=['Year', 'Val1'])

# Merge the dataframes based on the 'Year' column
merged_df = pd.merge(frederiksberg_df, københavn_df, on='Year', how='outer')

merged_df
# Out:
# [('2004', 1514486), ('2005', 2009537), ('2006', 2351355), ('2007', 2147494), ('2008', 1939642), ('2009', 1729699), ('2010', 1876651), ('2011', 1856537), ('2012', 1979362), ('2013', 2148561), ('2014', 2358001), ('2015', 2710328), ('2016', 2846295), ('2017', 2972087), ('2018', 3067454), ('2019', 3078192), ('2020', 3127619), ('2021', 3078176), ('2022', 2958895)]
#     Year     Val2     Val1
# 0   2004  1831863  1514486
# 1   2005  2432527  2009537
# 2   2006  2967807  2351355
# 3   2007  2689005  2147494
# 4   2008  2411340  1939642
# 5   2009  2169275  1729699
# 6   2010  2404517  1876651
# 7   2011  2476094  1856537
# 8   2012  2603080  1979362
# 9   2013  2780182  2148561
# 10  2014  3043468  2358001
# 11  2015  3360457  2710328
# 12  2016  3514799  2846295
# 13  2017  3671493  2972087
# 14  2018  3744034  3067454
# 15  2019  3762944  3078192
# 16  2020  3792786  3127619
# 17  2021  3763303  3078176
# 18  2022  3640595  2958895

# %%
# Just run this once, do not change it.

import matplotlib.pyplot as plt

def plot_values(df):
    """ Plots lineplot of the market values for Frederiksberg and Copenhagen.
    
    Args: 
        df: a dataframe containing Year, Frederiksberg, and Copenhagen columns
    """
    labels = [f'{year}' for year in df['Year']]
    
    plt.figure(figsize=(10, 6))
    plt.grid(color='black', linestyle='-', linewidth=0.1, axis='x')
    plt.plot(range(len(df)), df['Val1'], color='blue', label='Frederiksberg')
    plt.plot(range(len(df)), df['Val2'], color='red', label='Copenhagen')
    plt.yscale("log")
    plt.xticks(range(len(df)), labels, rotation='horizontal')
    plt.xlabel('Year')
    plt.ylabel('Market Value of Apartments')
    plt.legend()

# Call the function with the merged dataframe
plot_values(merged_df)

# %% [markdown]
# # Part 5: Bonus Exercises $-$ Traffic Data in Copenhagen
#
# This set of bonus exercises allows you to apply the tools that you have learned in session 2 to 5. Note that they are not mandatory $-$ rather, our hopes are the exercises will provide you with an additional opportunity to (i) strenghten your data structuring skills and (ii) see how you have already learned a series of skills that work nicely together.
#
# In this set of bonus exercises, you will be working with traffic data from Copenhagen Municipality.
#
# The municipality have made the data openly available through the [opendata.dk](http://www.opendata.dk/) platform. We will use the data from traffic counters to construct a dataset of hourly traffic. We will use this data to get basic insights on the development in traffic over time and relate it to weather. The gist here is to practice a very important skill in Data Science: being able to quickly fetch data from the web and structure it so that you can work with it. Scraping usually gets a bit more advanced than what we will do today, but the following exercises should give you a taste for how it works. The bulk of these exercise, however, revolve around using the Pandas library to structure and analyze data.

# %% [markdown]
# ## Part 5.5.A: Getting some data to work with
#
# Hence follows a simple scraping exercise where you (1) collect urls for datasets in the webpage listing data on traffic counters and (2) use these urls to load the data into one dataframe.
#
# > **Ex. 5.5.1:** *(Bonus)* Using the requests module, extract the html markup of the webpage data.kk.dk/dataset/faste-trafiktaellinger and store it as a string in a new variable.

# %%
# YOUR CODE HERE
raise NotImplementedError()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20864\1067236896.py in <module>
#       1 # YOUR CODE HERE
# ----> 2 raise NotImplementedError()
#
# NotImplementedError:

# %% [markdown]
# > **Ex. 5.5.2:** *(Bonus)* Using the re module, extract a list of all the urls in the html string and store them in a new variable.
#
# > _Hint:_ Try using the re.findall method. You may want to Google around to figure out how to do this. Searching for something along the lines of "extract all links in html regex python" and hitting the first StackOverflow link will probably get you farther than reading elaborate documentation.

# %%
import re 

# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# > **Ex. 5.5.3:** *(Bonus)* Create a new variable `datalinks` that only contains the links that point to downloadable traffic data sheets. Some links may be preset more than once on the page. To get the unique links use the `set()` function on `datalinks`.
#
# > _Hint:_ You want to filter the results from above. For example to only include urls with the term 'download' in them.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# > **Ex. 5.5.4:** *(Bonus)* Using pd.read_excel method, load the datasets into a list. Your resulting variable should hold a list of Pandas dataframes.
#
# > _Hint:_ you may want to set the `skiprows` keyword argument.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# > **Ex. 5.5.5:** *(Bonus)* Merge the list of dataframes into a single dataframe.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ## Part 5.5.B Structuring your data
#
# If you successfully completed the previous part, you should now have a dataframe with about 183.397 rows (if your number of rows is close but not the same, worry not—it matters little in the following). Well done! But the data is still in no shape for analysis, so we must clean it up a little.
#
# 161.236 rows (and 30 columns) is a lot of data. ~3.3 MB by my back-of-the-envelope calculations, so not "Big Data", but still enough to make your CPU heat up if you don't use it carefully. Pandas is built to handle fairly large dataframes and has advanced functionality to perform very fast operations even when the size of your data grows huge. So instead of working with basic Python we recommend working pandas built-in procedures as they are constructed to be fast on dataframes.
#
# Nerd fact: the reason pandas is much faster than pure Python is that dataframes access a lower level programming languages (namely C, C++) which are multiple times faster than Python. The reason it is faster is that it has a higher level of explicitness and thus is more difficult to learn and navigate.
#
# > **Ex. 5.5.6:** *(Bonus)* Reset the row indices of your dataframe so the first index is 0 and the last is whatever the number of rows your dataframe has. Also drop the column named 'index' and the one named `Spor`.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# > **Ex. 5.5.7:** *(Bonus)* Rename variables from Danish to English using the dictionary below.
#
# ```python
# dk_to_uk = {
#     'Vejnavn':'road_name',
#     '(UTM32)':'UTM32_north',
#     '(UTM32).1':'UTM32_east',
#     'Dato':'date',
#     'Vej-Id':'road_id'
# }
# ```

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# Python is quite efficient. For example, when you create a new dataframe by manipulating an old one, Python notices that—apart from some minor changes—these two objects are almost the same. Since memory is a precious resource, Python will represent the values in the new dataframe as references to the variables in the old dataset. This is great for performance, but if you for whatever reason change some of the values in your old dataframe, values in the new one will also change—and we don't want that! Luckily, we can break this dependency.
#
# > **Ex. 5.5.8:** *(Bonus)* Break the dependencies of the dataframe that resulted from Ex. 5.2.7 using the `.copy` method. Delete all other dataframes.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# Once you have structured appropriately, something that you will want to do again and again is selecting subsets of the data. Specifically, it means that you select specific rows in the dataset based on some column values.
#
# >**Ex. 5.5.9:** *(Bonus)* Create a new column in the dataframe called total that is True when the last letter of road_id is T and otherwise False.
#
# > _Hint:_ you will need the `pd.Series.str` attribute for this.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# > **Ex. 5.5.10:** *(Bonus)* Select rows where total is True. Delete all the remaining observations.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# > **Ex. 5.5.11:** *(Bonus)* Make two datasets based on the lists of columns below. Call the dataset with spatial columns data_geo and the other data.
#
# ```python
# # Columns for `geo_data`, stored in `geo_columns`
# spatial_columns = ['road_name', 'UTM32_north', 'UTM32_east']
#
# # Columns for `data`, stored in `select_columns`
# hours = ['kl.{}-{}'.format(str(h).zfill(2), str(h+1).zfill(2)) for h in range(24)]
# select_columns = ['road_name', 'date'] + hours
# ```

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# > **Ex. 5.5.12:** *(Bonus)* Drop the duplicate rows in data_geo.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# **Formatting: wide and narrow format**
#
# When talking about two-dimensional data (matrices, tables or dataframes, we can call it many things), we can either say that it is in wide or long format (see explanation here, "wide" and "long" are used interchangably). In Pandas we can use the commands stack and unstack to move between these formats.
#
# The wide format has the advantage that it often requires less storage and is easier to read when printed. On the other hand the long format can be easier for modelling, because each observation has its own row. Turns out that the latter is what we most often need.
#
# > **Ex. 5.5.13:** *(Bonus)* Turn the dataset from wide to long so hourly data is now vertically stacked. Store this dataset in a dataframe called data. Name the column with hourly information hour_period. Your resulting dataframe should look something like this.
#
# > _Hint:_ pandas' melt function may be of use.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# **Categorical data**
#
# Categorical data can contain Python objects, usually strings. These are smart if you have variables with string observations that are long and often repeated, e.g. with road names.
#
# > **Ex. 5.5.14:** *(Bonus)* Use the `.astype` method to convert the type of the road_name column to categorical.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ## Part 5.5.C:  Structure temporal data
#
# Pandas has native support for working with temporal data. This is handy as much 'big data' often has time stamps which we can make Pandas aware of. Once we have encoded temporal data it can be used to extract information such as the hour, second etc.
#
# > **Ex. 5.5.15:** *(Bonus)* Create a new column called hour which contains the hour-of-day for each row.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# >**Ex. 5.5.16:** *(Bonus)* Create a new column called time, that contains the time of the row in datetime format. Delete the old temporal columns (hour, hour_period, date) to save memory.
#
# > _Hint:_ try making an intermediary series of strings that has all temporal information for the row; then use pandas to_datetime function where you can specify the format of the date string.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# > **Ex. 5.5.17:** *(Bonus)* Using your time column make a new column called weekday which stores the weekday (in values between 0 and 6) of the corresponding datetime.
#
# > _Hint:_ try using the dt method for the series called time; dt has some relevant methods itself.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ## Part 5.5.D: Statistical descriptions of traffic data
#
# > **Ex. 5.5.18:** *(Bonus)* Print the "descriptive statistics" of the traffic column. Also show a kernel density estimate of the values.
#
# > _Hint:_ Use the describe method of pandas dataframes for the first task. Use seaborn for the second.

# %%
import seaborn as sb

# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# > **Ex. 5.5.19:** *(Bonus)* Which road has the most average traffic?

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# > **Ex. 5.5.20:** *(Bonus)* Compute annual, average road traffic during day hours (9-17). Which station had the least traffic in 2013? Which station has seen highest growth in traffic from 2013 to 2014?

# %%
# YOUR CODE HERE
raise NotImplementedError()
